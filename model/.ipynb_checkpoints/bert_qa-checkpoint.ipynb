# %%
import torch
import torch.nn as nn
import pandas as pd
import os
import numpy as np
from torch.utils.data import DataLoader
import tokenizers

# %%
# read the datasets. They are divided in test and train
train = pd.read_csv('../data/train.csv')
print(f'Lenght of train data is {len(train):,} observations')
# drop missing values
train = train.dropna()
print(f'Lenght of train data is {len(train):,} observations')
train.head(7)
# Out:
# Lenght of train data is 27,481 observations
# Lenght of train data is 27,480 observations
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
# 5  28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6  6e0c6d75b1  2am feedings for the baby are fun when he is a...
#
#                                        selected_text sentiment
# 0                I`d have responded, if I were going   neutral
# 1                                           Sooo SAD  negative
# 2                                        bullying me  negative
# 3                                     leave me alone  negative
# 4                                      Sons of ****,  negative
# 5  http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                fun  positive

# %%
#train = train.iloc[0:300]
# split dataset into training and validation 
from sklearn.model_selection import train_test_split
train_data, val_data = train_test_split(train,
                              random_state = 42,
                              stratify = train[['sentiment']],
                              test_size = 0.1)

# %%
# repeat for test
test = pd.read_csv('../data/test.csv')
print(f'Lenght of the test data is {len(test):,} observations')
# Out:
# Lenght of the test data is 3,534 observations

# %%
from tokenizers import BertWordPieceTokenizer
tokenizer_manual = BertWordPieceTokenizer('../models_trained/bert-base-uncased-vocab.txt', lowercase=True)

# %%
# test
from transformers import BertTokenizerFast
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
max_seq_length = 180

class Tweet_Loader(object):
    '''
    1. tokenize the text
    2. find the indices of the selected text in the original text
    3. append the question to the original text and modify original indexes
    4. identify start index and end index
    5. identify start and end index
    '''

    def __init__(self, text, selected_text, sentiment, textID):
        
        # define the text column from the dataframe
        self.text_column = text.tolist()
    
        # define sentiment
        self.sentinent = sentiment.tolist()
        
        # define selected text
        self.selected_text = selected_text.tolist()
    
        # define the label column and transform it to list
        self.textID = textID.tolist()
        
    # iter method to get each element at the time and tokenize it using bert        
    def __getitem__(self, index):
        
        sentinent = self.sentinent[index]
        text_id = self.textID[index]
        text = self.text_column[index]
        selected_text = self.selected_text[index]
        
        # clean text and selected text
        text = " ".join(str(text).split())
        selected_text = " ".join(str(selected_text).split())
        
        # find beggining of character
        #target_char_idx_start = text.index(selected_text)
        #target_char_idx_end = target_char_idx_start + len(selected_text)
        #print(text, selected_text, '', target_char_idx_start, target_char_idx_end)
        # get tokenized text
        tokenized_text = tokenizer.tokenize(text)
        tokenized_selected_text = tokenizer.tokenize(selected_text)
        #tokenized_text = tokenizer_manual.encode(text).tokens
        #tokenized_selected_text = tokenizer_manual.encode(selected_text).tokens
        
        # find the spans of the answer
        start_span_index = -1
        end_span_index = -1
        
        len_sel_text = len(tokenized_selected_text)
        
        # define the start and end index of the selected text. We iterate over the original tweet and
        # identify the point where the first word of the original text matches the first word of the selected
        # text. Then if traversing the substring of original tweet is the same as the selected tweet
        # then get the start and end spans
        for index in (i for i, e in enumerate(tokenized_text) if e == tokenized_selected_text[0]):
            if tokenized_text[index: index+len_sel_text] == tokenized_selected_text:
                start_span_index = index
                end_span_index = index + len_sel_text - 1
                break
                
        # use the encode plus function
        dictionary_inputs = tokenizer.encode_plus(sentinent, text, 
                                                  max_length = max_seq_length,
                                                  #truncation_strategy  ='do_not_truncate', 
                                                  add_special_tokens = True,
                                                  pad_to_max_length = True, padding_side='Right', 
                                                  is_pretokenized = False, return_token_type_ids=True,
                                                  return_attention_mask=True,
                                                  return_offsets_mapping = True,
                                                  return_tensors = 'pt')
        
        # create the input by adding the CLS token, the SEP token for separaring the question and the end of the
        # whole sentence
        #input_sentence = ['CLS'] + [sentinent] + ['SEP'] + tokenized_text + ['SEP']
        #inp=dictionary_inputs.get('input_ids')
        #inp = inp[0].tolist()
        #offsets = dictionary_inputs.get('offset_mapping')[0]
        start_span_index += 3
        end_span_index +=  3
        
        #tweet_offsets = dictionary_inputs.get('offset_mapping')[0]
        #filtered_output = ''
        #for ix in range(start_span_index, end_span_index):
            #print(text[tweet_offsets[ix][0]:tweet_offsets[ix][1]])
        #    filtered_output += text[tweet_offsets[ix][0]:tweet_offsets[ix][1]]
        #    if (ix+1) < len(tweet_offsets) and tweet_offsets[ix][1] < tweet_offsets[ix+1][0]:
        #        filtered_output += " "
                    
        #print(f'original was:{text}, and selected: {selected_text}',
        #      f'what we get back: {tokenizer.decode(inp[start_span_index:end_span_index+1])}',
        #      f'and f output {filtered_output}')
        
        return [dictionary_inputs, start_span_index, end_span_index, text_id, selected_text ]
  
    def __len__(self):
        return len(self.text_column)

# %%
#train_data
#example[0].keys()

# %%
#print(train['text'].iloc[12], train['selected_text'].iloc[12])
#targets_(train['text'].iloc[12], train['selected_text'].iloc[12])
#print(tokenizer.decode([20754]))

# %%
# create a class to process the traininga and test data
batch_size = 4
training_data = Tweet_Loader(train_data['text'],
                             train_data['selected_text'], 
                             train_data['sentiment'],
                             train_data['textID'])

valid_data =  Tweet_Loader(val_data['text'],val_data['selected_text'], val_data['sentiment'], val_data['textID'])

# use the dataloaders class to load the data
dataloaders_dict = {'train': DataLoader(training_data, batch_size=batch_size, shuffle=False, num_workers=4),
                    'val': DataLoader(valid_data, batch_size=batch_size, shuffle=True, num_workers=4)
                   }

dataset_sizes = {'train':len(training_data),
                 'val':len(valid_data)}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
'''
from torch.utils.data import Dataset, DataLoader

a = Tweet_Loader(train['text'],train['selected_text'], train['sentiment'], train['textID'])

# use the dataloaders class to load the data
dataloaders_dict = {'train': DataLoader(a, batch_size=1, shuffle=True, num_workers=4)}

dataset_sizes = {'train':len(a)}
'''
# Out:
# "\nfrom torch.utils.data import Dataset, DataLoader\n\na = Tweet_Loader(train['text'],train['selected_text'], train['sentiment'], train['textID'])\n\n# use the dataloaders class to load the data\ndataloaders_dict = {'train': DataLoader(a, batch_size=1, shuffle=True, num_workers=4)}\n\ndataset_sizes = {'train':len(a)}\n"

# %%
#train.loc[44]['text']
example = next(iter(dataloaders_dict.get('train')))
#tokenizer_manual.decode(example[0].get('input_ids')[2][0].tolist())
#example[0].get('input_ids')[0][0].tolist()
#[example[1][1].item():example[2][1].item()+1]

#print(example[1],example[2])

# %%
#print(example[0].get('offset_mapping')[0][0])

# %%
"""#example[4]
#example[0].get('input_ids')[0][0][example[1][0].item():example[2][0].item()+1]
#tokenizer_manual.decode(skip_special_tokens=True)
#import tokenizers.decoders
def is_subtoken(word):
    if word[:2] == "##":
        return True
    else:
        return False

def original_string(tokens):
    tokens = ['why', 'isn', "##'", '##t', 'Alex', "##'", 'text', 'token', '##izing']
    restored_text = []
    for i in range(len(tokens)):
        if not is_subtoken(tokens[i]) and (i+1)<len(tokens) and is_subtoken(tokens[i+1]):
            restored_text.append(tokens[i] + tokens[i+1][2:])
            if (i+2)<len(tokens) and is_subtoken(tokens[i+2]):
                restored_text[-1] = restored_text[-1] + tokens[i+2][2:]
        elif not is_subtoken(tokens[i]):
            restored_text.append(tokens[i])
    return restored_text
"""
# Out:
# '#example[4]\n#example[0].get(\'input_ids\')[0][0][example[1][0].item():example[2][0].item()+1]\n#tokenizer_manual.decode(skip_special_tokens=True)\n#import tokenizers.decoders\ndef is_subtoken(word):\n    if word[:2] == "##":\n        return True\n    else:\n        return False\n\ndef original_string(tokens):\n    tokens = [\'why\', \'isn\', "##\'", \'##t\', \'Alex\', "##\'", \'text\', \'token\', \'##izing\']\n    restored_text = []\n    for i in range(len(tokens)):\n        if not is_subtoken(tokens[i]) and (i+1)<len(tokens) and is_subtoken(tokens[i+1]):\n            restored_text.append(tokens[i] + tokens[i+1][2:])\n            if (i+2)<len(tokens) and is_subtoken(tokens[i+2]):\n                restored_text[-1] = restored_text[-1] + tokens[i+2][2:]\n        elif not is_subtoken(tokens[i]):\n            restored_text.append(tokens[i])\n    return restored_text\n'

# %%
#s = reconstruct_string(example[1][1].item(), example[2][1].item(), example[0].get('input_ids')[1][0])
#s = tokenizert_manual.example[0].get('input_ids')[1][0][example[1][1].item():example[2][1].item()+1].tolist(),
#                           skip_special_tokens=True)
#for i in example[0].get('input_ids')[0][0]:
#        print(tokenizer_manual.id_to_token(i))
#print(f'original text is  """{example[4][1]}""" and reconstructed is '
#      f'""" {s} """')


#example[0].keys()

# %%
def reconstruct_string(start_index, end_index, input_ids):
    # get the actual span tokes using the start_span and end_span
    #original_tokens = input_ids[start_index:end_index+1]
    original_tokens = tokenizer.decode(input_ids.tolist()[start_index:end_index+1])
    # move to string 
    #original_string = ' '.join([x for x in original_tokens])

    return original_tokens
    
a = reconstruct_string(example[1][0].item(), example[2][0].item(), 
                   example[0].get('input_ids')[0][0])

# %%
a
# Out:
# 'morning, just checking you can still find your twhirl'

# %%
#tokens_ =  tokenizer.convert_ids_to_tokens(example[0].get('input_ids')[0][0][example[0][0]:example[2][0]])
#tokens_
#example[0].get('input_ids')[0][0]
#a= example[1][0].item()
#b= example[2][0].item()+1
#print(example[0].get('input_ids')[0][0][example[1][0].item():example[2][0].item()+1]
#     )
#text_r = ' '.join([x for x in tokens_])
#print(text_r)
#fine_text = text.replace(' ##', '')

# %%
#a = tokenizer.tokenize('sigh.. stayed up late cause was on a role w/ assessment, now I`m so tired my eyes r stinging & my head hurts.. & I still need 500 words')
#len(a)
# import the model
from transformers import BertForQuestionAnswering, BertConfig
config  = BertConfig()
model = BertForQuestionAnswering.from_pretrained(
    "bert-base-uncased", config = config)

# %%
# check the model
model
# Out:
# BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# define jaccard metric
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    if (len(a)==0) & (len(b)==0): 
        return 0.5
    c = a.intersection(b)
    score = float(len(c)) / (len(a) + len(b) - len(c))
    return score

# %%
#jaccard(s, example[4][1])

#print(s, example[6][1])
#tokenizer1.decode()
#example[0].get('input_ids')[0][0][example[1][0].item():example[2][0].item()+1]

# %%
'''
# ======== Reconstruct Answer ========
    # Find the tokens with the highest `start` and `end` scores.
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)

    # Get the string versions of the input tokens.
    tokens = tokenizer.convert_ids_to_tokens(input_ids)

    # Start with the first token.
    answer = tokens[answer_start]

    # Select the remaining answer tokens and join them with whitespace.
    for i in range(answer_start + 1, answer_end + 1):
        
        # If it's a subword token, then recombine it with the previous token.
        if tokens[i][0:2] == '##':
            answer += tokens[i][2:]
        
        # Otherwise, add a space then the token.
        else:
            answer += ' ' + tokens[i]

    print('Answer: "' + answer + '"')
    
'''
# Out:
# '\n# ======== Reconstruct Answer ========\n    # Find the tokens with the highest `start` and `end` scores.\n    answer_start = torch.argmax(start_scores)\n    answer_end = torch.argmax(end_scores)\n\n    # Get the string versions of the input tokens.\n    tokens = tokenizer.convert_ids_to_tokens(input_ids)\n\n    # Start with the first token.\n    answer = tokens[answer_start]\n\n    # Select the remaining answer tokens and join them with whitespace.\n    for i in range(answer_start + 1, answer_end + 1):\n        \n        # If it\'s a subword token, then recombine it with the previous token.\n        if tokens[i][0:2] == \'##\':\n            answer += tokens[i][2:]\n        \n        # Otherwise, add a space then the token.\n        else:\n            answer += \' \' + tokens[i]\n\n    print(\'Answer: "\' + answer + \'"\')\n    \n'

# %%
import logging
logging.basicConfig(level = logging.INFO, filename ='../logs/bert_tweet_extraction_160_nofinetune.txt', filemode ='w', 
                   format = '%(name)s -%(levelname)s - %(message)s')

# %%
import torch.optim as optim 
from torch.optim import lr_scheduler, AdamW
#criterion = nn.CrossEntropyLoss()


#lrmain = 1e-3

optim1 = optim.AdamW(model.parameters(), lr=3e-5, betas=(0.9, 0.999))
    #[
    #    {"params":model.bert.parameters(),"lr": lrmain},
   #])

optimizer_ft = optim1

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=2, gamma=0.1)

# %%
import torch.nn.functional as F
#import torch.nn.functional as F
import copy 
import time
number_steps = 10
print(number_steps)

def train_model(model, optimizer, scheduler, num_epochs=3):
    best_eval_jac = 0.0
    for epoch in range(num_epochs):
        #zero the model gradients
        model.zero_grad()
        print(f'starting epoch {epoch+1} out of {num_epochs}')
        training_loss = []
        training_jaccard = []
        val_loss = []
        val_jaccard = []
        outputs_ = []
        labels_ = []

        epoch_loss = 0.0

        # track number of batches and number of iterations
        counter = 0
        iterations = 0

        # Iterate over data, feeding inputs, attention masks and labels
        model.train()
        for i, (dict_param, start_position, end_position, tweet_id, selected_text) in enumerate(dataloaders_dict['train']):
            # add a counter that will register how many examples we have fed to the
            # model
            counter+= batch_size
            iterations+=1
            # move the sequences, labels and masks to the GPU
            inputs = dict_param.get('input_ids').to(device).squeeze()
            #print(inputs.shape)
            token_type_ids = dict_param.get('token_type_ids').to(device).squeeze()
            #print(token_type_ids.shape)
            attention_mask = dict_param.get('attention_mask').to(device).squeeze()
            #print(attention_mask.shape)
            start_pos = start_position.to(device)
            end_pos = end_position.to(device)
            

            # feed the sequences to the model, specifying the attention mask
            loss, start_scores, end_scores = model(inputs, token_type_ids = token_type_ids, 
                                                   attention_mask = attention_mask, 
                                                   start_positions = start_pos,
                                                   end_positions = end_pos)
            
            # 
            training_loss.append(loss.item())
            epoch_loss+=loss.item()
            loss.backward()
            #print(start_scores, start_scores.shape)
            
                        
            # update every number of accumulation
            if (i+1) % number_steps == 0:
                
                optimizer.step()                            # Now we can do an optimizer step
                model.zero_grad()                           # Reset gradients tensors
      
            # only present the information 
            if counter%100 == 0:
                
                start_preds=torch.argmax(start_scores,dim=1).cpu().detach().numpy()
                end_preds=torch.argmax(end_scores,dim=1).cpu().detach().numpy()
                start_index = start_pos.cpu().cpu().detach().numpy()
                end_index = end_pos.cpu().cpu().detach().numpy()
                inputs = inputs.cpu().detach().numpy()
                       
                for i in range(inputs.shape[0]):
                    # here we reconstruct the string with original index
                    original_string = reconstruct_string(start_index[i], end_index[i], inputs[i])
                    # repeat with what we found
                    pred_string = reconstruct_string(start_preds[i], end_preds[i], inputs[i])
                    #print(type(selected_text),type(pred_string))
                    jaccard_score = jaccard(selected_text[i],pred_string)
                    training_jaccard.append(jaccard_score)
                    #print(f'the original is {original_string}, the predicted is {pred_string}')
                    
                print(f'reconstruction is: {original_string} and original is: {selected_text[i]}')
                print(f'current loss is {epoch_loss/iterations} and jaccard',
                      f'is {np.mean(training_jaccard):,.2%}')
                
        with torch.no_grad():
            model.eval()
            counter_val = 0
            iterations_val = 0
            
            for i, (dict_param, start_position, end_position, tweet_id, selected_text) in enumerate(dataloaders_dict['train']):
            # add a counter that will register how many examples we have fed to the
            # model
                counter+= batch_size
                iterations_val+=1
            # move the sequences, labels and masks to the GPU
                inputs = dict_param.get('input_ids').to(device).squeeze()
                token_type_ids = dict_param.get('token_type_ids').to(device).squeeze()
                attention_mask = dict_param.get('attention_mask').to(device).squeeze()
                start_pos = start_position.to(device)
                end_pos = end_position.to(device)

            # feed the sequences to the model, specifying the attention mask
                loss, start_scores, end_scores = model(inputs, token_type_ids = token_type_ids, 
                                                   attention_mask = attention_mask, 
                                                   start_positions = start_pos,
                                                   end_positions = end_pos)
            
                val_loss.append(loss.item())
                
                if counter%10 == 0:

                    start_preds=torch.argmax(start_scores,dim=1).cpu().detach().numpy()
                    end_preds=torch.argmax(end_scores,dim=1).cpu().detach().numpy()
                    start_index = start_pos.cpu().cpu().detach().numpy()
                    end_index = end_pos.cpu().cpu().detach().numpy()
                    inputs = inputs.cpu().detach().numpy()
                       
                    for i in range(inputs.shape[0]):
                        #original_string = reconstruct_string(start_index[i], end_index[i], inputs[i])
                        pred_string = reconstruct_string(start_preds[i], end_preds[i], inputs[i])
                        print(selected_text[i],pred_string)
                        jaccard_score = jaccard(selected_text[i],pred_string)
                        val_jaccard.append(jaccard_score)
                        
                
                        print(f'current validation loss is {np.sum(val_loss)/iterations_val} and'
                              f'jaccard score is {np.mean(val_jaccard):,.2%}')
                              
        print(f'For epoch {epoch+1} training loss is {np.sum(training_loss)/iterations}, \
        training accuracy is {np.mean(training_jaccard):,.2%}, Validation \
        loss is {np.sum(val_loss)/iterations_val} and validation accuracy is {np.mean(val_jaccard):,.2%}')
        jac_acc = np.mean(val_jaccard)
        if jac_acc >= best_eval_jac:
            best_eval_jac = jac_acc
            print(f'saving the model with jac_acc  {jac_acc:,.2%} ')
            torch.save(model.state_dict(), '../models_trained/bert_tweet_extraction_no_finetuned.pth')
            #model.config.to_json_file('../models_trained/bert_base_uncased.json')
            torch.save(model, '../models_trained/bert_tweet_extraction_no_finetuned.bin')
            #torch.save(optimizer_ft.state_dict(), 
            #           'bert_tweet_classification_state_dict_280_no_finetuned_optimizer.pth')
            #model_to_save = model.module if hasattr(model, 'module') else model  # Only save the model it-self
            #output_model_file = os.path.join("bert_tweet_classification_280_no_finetuned_model.bin")

        else:
            print(f'model did not improve')
        
        logging.info(f'We completed epoch {epoch+1} with a training loss of {np.sum(training_loss)/iterations} \
        a jac score of {np.mean(training_jaccard):,.2%}, Validation \
        loss is {np.sum(val_loss)/iterations_val} and validation accuracy is {np.mean(val_jaccard):,.2%}')
      
    return model
# Out:
# 10

# %%
# time to train 
model.to(device)
model_ft1 = train_model(model, optimizer_ft, exp_lr_scheduler,
                       num_epochs=3)
# Out:
# starting epoch 1 out of 3
# reconstruction is: it ` s after midnight & i hear the shower calling me - technically it ` s not twice in one day since it ` s morning - - i ` m not very'green '. and original is: It`s after midnight & I hear the shower calling me- Technically it`s not twice in one day since it`s morning-- I`m not very 'green'.
# current loss is 5.147036838531494 and jaccard is 33.46%
# reconstruction is: thanks and original is: thanks
# current loss is 4.937373332977295 and jaccard is 21.42%
# reconstruction is: disappointment really sucks! and original is: Disappointment really sucks!
# current loss is 4.714729283650716 and jaccard is 15.11%
# reconstruction is: hate and original is: hate
# current loss is 4.442237493991851 and jaccard is 17.48%
# reconstruction is: happy and original is: Happy
# current loss is 4.191350318908691 and jaccard is 14.94%
# reconstruction is: i need a code and original is: I need a code
# current loss is 3.971504987080892 and jaccard is 14.88%
# reconstruction is: love and original is: love
# current loss is 3.784695179803031 and jaccard is 17.93%
# reconstruction is: haha, i came home from a long night out, and all i saw on tweetie was khayyam wakil. i usually don ` t announce and * * * * - lol and original is: Haha, i came home from a long night out, and all i saw on Tweetie was Khayyam Wakil. I usually don`t announce and **** - LOL
# current loss is 3.620623301267624 and jaccard is 19.68%
# reconstruction is: i love b & bws new scents? and original is: I love B&BWs new scents ?
# current loss is 3.459773578643799 and jaccard is 21.44%
# reconstruction is: dirty and original is: dirty
# current loss is 3.324927415847778 and jaccard is 23.48%
# reconstruction is: in the mood to listen to some reg stuff ( sir told me : u used to be a huge fan of mine but now it seems you ` ve forgotten my songs!!! ) ) and original is: in the mood to listen to some Reg stuff (Sir told me: U used to be a huge fan of mine but now it seems you`ve forgotten my songs!!!) )
# current loss is 3.2063074762170967 and jaccard is 26.03%
# reconstruction is: forget completely abt uploading the assignemtn. only remmebered cos of ur twit and original is: Forget completely abt uploading the assignemtn. Only remmebered cos of ur twit
# current loss is 3.1089571249485015 and jaccard is 27.23%
# reconstruction is: dentist but the chicks hot so thats a plus and original is: Dentist but the chicks hot so thats a plus
# current loss is 3.0018633110706623 and jaccard is 31.72%
# reconstruction is: beautiful and original is: beautiful
# current loss is 2.9198643597534724 and jaccard is 31.10%
# reconstruction is: his snoring is so annoying n it keeps me from sleeping ( like right now, lol ) but i honestly wud miss it if it eva left i love him. and original is: His snoring is so annoying n it keeps me from sleeping (like right now, lol) but I honestly wud miss it if it eva left I love him.
# current loss is 2.8447958908081055 and jaccard is 31.80%
# reconstruction is: perky purple nail polish isn ` t as perky when its chipped and original is: perky purple nail polish isn`t as perky when its chipped
# current loss is 2.770581434518099 and jaccard is 32.07%
# reconstruction is: naisee. is it bad that i can see lens flares all arond me while listening to it? xd cant really catch what they ` re saying tho and original is: naisee. is it bad that i can see lens flares all arond me while listening to it? XD cant really catch what they`re saying tho
# current loss is 2.7005266481287338 and jaccard is 34.39%
# reconstruction is: i still think their disbanding is a loss. and original is: I still think their disbanding is a loss.
# current loss is 2.6460566491550868 and jaccard is 33.71%
# reconstruction is: you are so weird. and original is: You are so weird.
# current loss is 2.590021531330912 and jaccard is 33.27%
# reconstruction is: off to do pilates now! tweet y ` all soon! and original is: Off To Do Pilates Now! Tweet Y`all Soon!
# current loss is 2.535017185926437 and jaccard is 34.05%
# reconstruction is: made me sad. and original is: made me sad.
# current loss is 2.4855602654956637 and jaccard is 33.53%
# reconstruction is: i don ` t know if i can make that one. and original is: I don`t know if I can make that one.
# current loss is 2.4387541433897884 and jaccard is 33.59%
# reconstruction is: thanks for your follow and original is: thanks for your follow
# current loss is 2.3942480239660844 and jaccard is 33.56%
# reconstruction is: fuckkk i need sleepppppppp lol, happy mothers day mummy and original is: fuckkk i need sleepppppppp lol, happy mothers day mummy
# current loss is 2.3653959571321805 and jaccard is 34.80%
# reconstruction is: i ` m glad for you i ` m fine and original is: I`m glad for you I`m fine
# current loss is 2.327807997751236 and jaccard is 36.35%
# reconstruction is: watching the 3rd episode of jonas and original is: Watching the 3rd episode of JONAS
# current loss is 2.295791731751882 and jaccard is 37.88%
# reconstruction is: me neither and original is: me neither
# current loss is 2.25873315638966 and jaccard is 38.08%
# reconstruction is: cant contain myself, tooooooo excited and original is: cant contain myself, tooooooo excited
# current loss is 2.225291485232966 and jaccard is 38.60%
# reconstruction is: so, finally finished catching up with your blog - no mention of any wedding details... do tell, at some point. and original is: So, finally finished catching up with your blog - no mention of any wedding details... Do tell, at some point.
# current loss is 2.197796253212567 and jaccard is 40.49%
# reconstruction is: thank you for the re - tweet and original is: thank you for the re-tweet
# current loss is 2.1662032786210377 and jaccard is 41.57%
# reconstruction is: why?!!? and original is: why?!!?
# current loss is 2.1483518963475383 and jaccard is 41.37%
# reconstruction is: i ` m confused and sad and original is: I`m confused and sad
# current loss is 2.119032658189535 and jaccard is 41.67%
# reconstruction is: died! and original is: died!
# current loss is 2.102822643699068 and jaccard is 41.73%
# reconstruction is: love and original is: love
# current loss is 2.0829006010644577 and jaccard is 41.81%
# reconstruction is: omg i miss you so muuch and original is: omg i miss you so muuch
# current loss is 2.058158678122929 and jaccard is 42.16%
# reconstruction is: happy and original is: happy
# current loss is 2.028493690225813 and jaccard is 42.72%
# reconstruction is: that is sickening. and original is: that is sickening.
# current loss is 2.0034374749338304 and jaccard is 42.63%
# reconstruction is: i have nothing to dye. and original is: I have nothing to dye.
# current loss is 1.9860639845697503 and jaccard is 42.84%
# reconstruction is: feeling shattered and original is: feeling shattered
# current loss is 1.9698212161125281 and jaccard is 43.16%
# reconstruction is: : 3 hrs to go pa ako and original is: : 3 hrs to go pa ako
# current loss is 1.952662862867117 and jaccard is 43.46%
# reconstruction is: i miss you bby and original is: i miss you bby
# current loss is 1.9351181122442571 and jaccard is 44.39%
# reconstruction is: fight and original is: fight
# current loss is 1.9162794378825596 and jaccard is 44.46%
# reconstruction is: not fair! and original is: not fair!
# current loss is 1.902004080262295 and jaccard is 44.64%
# reconstruction is: worth and original is: worth
# current loss is 1.8886702407490124 and jaccard is 44.68%
# reconstruction is: thanks and original is: Thanks
# current loss is 1.8737074500719706 and jaccard is 45.25%
# reconstruction is: changing guitar strings.. getting ready to perform ` the climb ` at my cousins birthdayy and original is: Changing Guitar strings.. Getting Ready To Perform `THE CLIMB` at my cousins birthdayy
# current loss is 1.8590680615279986 and jaccard is 45.85%
# reconstruction is: had the best weekend ever and original is: had the best weekend EVER
# current loss is 1.8440661059288268 and jaccard is 45.62%
# reconstruction is: - promise - thanks and original is: - promise - thanks
# current loss is 1.8285880468040705 and jaccard is 46.15%
# reconstruction is: _ vegetable me 2 and original is: _Vegetable me 2
# current loss is 1.8126922327158403 and jaccard is 46.52%
# reconstruction is: . kind and original is: . Kind
# current loss is 1.8036142103672028 and jaccard is 46.63%
# reconstruction is: amazing and original is: amazing
# current loss is 1.7917399113785988 and jaccard is 46.54%
# reconstruction is: what ` s worse... and original is: what`s worse...
# current loss is 1.7840041480614588 and jaccard is 46.12%
# reconstruction is: i missed my favorite judge and now i can ` t sleep. and original is: I missed my favorite judge and now I can`t sleep.
# current loss is 1.7689631500559033 and jaccard is 46.72%
# reconstruction is: ohhh, how lovely! i ` m glad that you had a great time there. and original is: Ohhh, how lovely! I`m glad that you had a great time there.
# current loss is 1.7595922742287318 and jaccard is 46.20%
# reconstruction is: where is teng? and original is: Where is Teng?
# current loss is 1.750946330352263 and jaccard is 46.72%
# reconstruction is: sad and original is: sad
# current loss is 1.7412804013277803 and jaccard is 47.29%
# reconstruction is: guus ` s last game 2moz and original is: Guus`s last game 2moz
# current loss is 1.73114416477973 and jaccard is 47.19%
# reconstruction is: i misss youhhhhhhh and original is: i misss youhhhhhhh
# current loss is 1.7193095259008737 and jaccard is 47.08%
# reconstruction is: [SEP] and original is: on. Too slo
# current loss is 1.7111936620130377 and jaccard is 47.02%
# reconstruction is: outstanding! and original is: OUTSTANDING!
# current loss is 1.7032230025927226 and jaccard is 47.24%
# reconstruction is: hope and original is: hope
# current loss is 1.6904836470572675 and jaccard is 47.69%
# reconstruction is: ah so 15 months. i ` m sure he is advanced, and it ` s not you being biased they seem to grow up faster these days - now i sound old! and original is: Ah so 15 months. I`m sure he is advanced, and it`s not you being biased they seem to grow up faster these days - now I sound old!
# current loss is 1.6812121888129943 and jaccard is 47.89%
# reconstruction is: good luck and original is: good luck
# current loss is 1.671698548150441 and jaccard is 48.36%
# reconstruction is: slow dance rockin ` the * * * * out of my playlist and original is: SLOW DANCE ROCKIN` THE **** OUT OF MY PLAYLIST
# current loss is 1.6682213397696615 and jaccard is 47.81%
# reconstruction is: better and original is: better
# current loss is 1.659800216289667 and jaccard is 47.67%
# reconstruction is: [SEP] and original is: st jokin
# current loss is 1.6531126348900071 and jaccard is 47.68%
# reconstruction is: mama the boys gon be sweating her hard in pre k lol muah and original is: mama the boys gon be sweating her hard in Pre K lol muah
# current loss is 1.6475763465753241 and jaccard is 48.00%
# reconstruction is: bali!! can wait for it and original is: bali!! can wait for it
# current loss is 1.6387187595227186 and jaccard is 48.12%
# reconstruction is: summmmmerrrrr begins... yeahhhhhyaaaaaa and original is: summmmmerrrrr begins...yeahhhhhyaaaaaa
# current loss is 1.6325554779992588 and jaccard is 47.73%
# reconstruction is: waiting on the cue for kenny and original is: waiting on the cue for kenny
# current loss is 1.6215942866461617 and jaccard is 47.94%
# reconstruction is: [SEP] and original is: nd I am sure you will be fine
# current loss is 1.6136398614964016 and jaccard is 48.17%
# reconstruction is: cute and original is: cute
# current loss is 1.6082759529352189 and jaccard is 48.40%
# reconstruction is: they rock! and original is: they rock!
# current loss is 1.6057078279861032 and jaccard is 48.28%
# reconstruction is: hey, you change your twitter account, and you didn ` t even tell me... and original is: Hey, you change your twitter account, and you didn`t even tell me...
# current loss is 1.5978385801895245 and jaccard is 48.59%
# reconstruction is: has a bad headache and original is: Has a bad headache
# current loss is 1.59003207915624 and jaccard is 49.02%
# reconstruction is: very pretty and original is: Very pretty
# current loss is 1.5846547871514371 and jaccard is 49.37%
# reconstruction is: hi, i teach some chinese lessons on youtube... feel free to have a look and original is: Hi, I teach some Chinese lessons on youtube... Feel free to have a look
# current loss is 1.5819420461375993 and jaccard is 49.73%
# reconstruction is: wish and original is: wish
# current loss is 1.5765988665513504 and jaccard is 50.00%
# reconstruction is: hopefully and original is: hopefully
# current loss is 1.5692101616195486 and jaccard is 50.19%
# reconstruction is: wait till england wc t20 and original is: wait till england WC t20
# current loss is 1.5628471938371657 and jaccard is 50.39%
# reconstruction is: _ devil1 big brother quiz? what?! i ` m too busy rocking out on guitar hero, i didn ` t notice any such thing and original is: _Devil1 Big Brother quiz? What?! I`m too busy rocking out on Guitar Hero, I didn`t notice any such thing
# current loss is 1.556478965046965 and jaccard is 50.46%
# reconstruction is: i found out about it a little late and couldn ` t afford it and original is: I found out about it a little late and couldn`t afford it
# current loss is 1.5513356660342799 and jaccard is 50.67%
# reconstruction is: happy and original is: happy
# current loss is 1.5460750541198685 and jaccard is 50.69%
# reconstruction is: stuck and original is: stuck
# current loss is 1.5394381096249534 and jaccard is 50.93%
# reconstruction is: recording an acoustic track! for you sexy kids! and original is: Recording an acoustic track! For you sexy kids!
# current loss is 1.5313311203227324 and jaccard is 51.24%
# reconstruction is: what ` s wrong and original is: what`s wrong
# current loss is 1.523900582083436 and jaccard is 51.43%
# reconstruction is: ouch. and original is: Ouch.
# current loss is 1.5176447774761024 and jaccard is 51.14%
# reconstruction is: morning ( ish ) hows everyone? and original is: morning(ish) hows everyone?
# current loss is 1.5142828647115014 and jaccard is 51.19%
# reconstruction is: lol, yeah i do it cuz it just seems that way sometimes don ` * * * * and original is: LOL, yeah I do it cuz it just seems that way sometimes don`****
# current loss is 1.5098687432589155 and jaccard is 51.38%
# reconstruction is: yet another road block to cross fro my family and original is: Yet another road block to cross fro my family
# current loss is 1.5073917357391782 and jaccard is 51.44%
# reconstruction is: . i ` m sure i forgot people though. and original is: .I`m sure I forgot people though.
# current loss is 1.500810992219946 and jaccard is 51.64%
# reconstruction is: star trek? me? nah. my dad is one for star trek right enough. today, i ` m off to see ` corlaine `. much more my style shezz. and original is: Star Trek? Me? Nah. My Dad is one for Star Trek right enough. Today, I`m off to see `Corlaine`. Much more my style Shezz.
# current loss is 1.4953085720798243 and jaccard is 51.92%
# reconstruction is: home * * * * and original is: home ****
# current loss is 1.490513199644704 and jaccard is 51.81%
# reconstruction is: hello twitter and original is: Hello twitter
# current loss is 1.4844509858146626 and jaccard is 51.91%
# reconstruction is: i can ` t sleep ugh!! and original is: I can`t sleep ugh!!
# current loss is 1.4825034340431815 and jaccard is 51.54%
# reconstruction is: you need to play something from mary poppins at them, everyone knows that ` s how rooms get tidy and original is: you need to play something from Mary Poppins at them, everyone knows that`s how rooms get tidy
# current loss is 1.4782470211014151 and jaccard is 51.57%
# reconstruction is: is suffering from hayfever, is drowsy from too much piriton, and original is: is suffering from hayfever, is drowsy from too much Piriton,
# current loss is 1.4728151870634139 and jaccard is 51.43%
# reconstruction is: going crazy, the pain is unbearable.. & i gotta wait till thursday!? and original is: going crazy, the pain is unbearable..& i gotta wait till thursday!?
# current loss is 1.4680692222775245 and jaccard is 51.19%
# reconstruction is: yukky rainy friday and original is: Yukky Rainy Friday
# current loss is 1.4632004556872629 and jaccard is 50.91%
# reconstruction is: wow! ever notice that some twitters have thousands of followers, yet they only follow a handful ( actually, less than two hands ) of peeps. and original is: wow! ever notice that some twitters have thousands of followers, yet they only follow a handful (actually, less than two hands) of peeps.
# current loss is 1.4605785434246064 and jaccard is 51.05%
# reconstruction is: knight online come back and original is: Knight Online Come Back
# current loss is 1.455904829572923 and jaccard is 51.28%
# reconstruction is: i want to know when the auditions are mander! text or... reply please! and original is: I want to know when the auditions are Mander! Text or...reply please!
# current loss is 1.450966402444185 and jaccard is 51.27%
# reconstruction is: we ` re awesome and original is: we`re awesome
# current loss is 1.4457970665612268 and jaccard is 51.50%
# reconstruction is: thanks and original is: thanks
# current loss is 1.4414342177143464 and jaccard is 51.87%
# reconstruction is: stupid, and original is: stupid,
# current loss is 1.437088517325265 and jaccard is 52.10%
# reconstruction is: thank and original is: thank
# current loss is 1.4334097632372154 and jaccard is 52.11%
# reconstruction is: recovering from my crazy family. i love them, but they ain ` t got it all i only see em a couple of times a year, so i guess i can deal. and original is: Recovering from my crazy family. I love them, but they ain`t got it all I only see em a couple of times a year, so I guess I can deal.
# current loss is 1.4298832124861602 and jaccard is 51.73%
# reconstruction is: whoops! and original is: Whoops!
# current loss is 1.4273507078709426 and jaccard is 51.79%
# reconstruction is: i really should be studying. i ` ll start soon : [ and original is: i really should be studying. I`ll start soon :[
# current loss is 1.4237948356418435 and jaccard is 51.79%
# reconstruction is: last day in exeter! had last session in gym, last breakfast.. last meeting coming up and original is: Last day in Exeter! Had last session in gym, last breakfast.. last meeting coming up
# current loss is 1.4217345194383102 and jaccard is 51.81%
# reconstruction is: love it there and original is: Love it there
# current loss is 1.4181839717186249 and jaccard is 51.86%
# reconstruction is: buy me a taco! haha. i don ` t want to stand in line and original is: buy me a taco! haha. i don`t want to stand in line
# current loss is 1.4152952643590313 and jaccard is 51.86%
# reconstruction is: follow me! and original is: follow me!
# current loss is 1.413689215225456 and jaccard is 51.92%
# reconstruction is: boingo connected without fuss this time, but it ` s slower ` n snail piss.. and original is: Boingo connected without fuss this time, but it`s slower`n snail piss..
# current loss is 1.4109684585688407 and jaccard is 51.85%
# reconstruction is: bomb! and original is: bomb!
# current loss is 1.4061641041714212 and jaccard is 52.06%
# reconstruction is: love and original is: love
# current loss is 1.4034594595843348 and jaccard is 52.22%
# reconstruction is: when in doubt go with the instincts. and original is: when in doubt go with the instincts.
# current loss is 1.4010635761318044 and jaccard is 52.52%
# reconstruction is: can this week get anymore horrible.. and original is: can this week get anymore horrible..
# current loss is 1.3989403057502487 and jaccard is 52.40%
# reconstruction is: outsider.. and original is: outsider..
# current loss is 1.3954854518826267 and jaccard is 52.38%
# reconstruction is: that sounds foreboding... and original is: that sounds foreboding...
# current loss is 1.3921237540443738 and jaccard is 52.59%
# reconstruction is: you aint invite me and original is: you aint invite me
# current loss is 1.387755019132756 and jaccard is 52.84%
# reconstruction is: beautiful and original is: beautiful
# current loss is 1.3857922236548095 and jaccard is 52.73%
# reconstruction is: super happy and original is: Super happy
# current loss is 1.3840140555544598 and jaccard is 52.48%
# reconstruction is: haha. weird?!? no sunshine for us and original is: haha. weird?!? no sunshine for us
# current loss is 1.3834328627874775 and jaccard is 52.55%
# reconstruction is: get up, you are not old! what did you do?! = o and original is: Get Up, You are NOT old! What did you do?! =O
# current loss is 1.3793882635498047 and jaccard is 52.79%
# reconstruction is: looking forward to and original is: Looking forward to
# current loss is 1.3752091990860682 and jaccard is 52.80%
# reconstruction is: im bored to death and original is: im bored to death
# current loss is 1.3718501565681667 and jaccard is 52.57%
# reconstruction is: [SEP] and original is: tired an
# current loss is 1.3694390571396797 and jaccard is 52.55%
# reconstruction is: dang and original is: Dang
# current loss is 1.366990951817165 and jaccard is 52.40%
# reconstruction is: slower and original is: slower
# current loss is 1.363108715891838 and jaccard is 52.33%
# reconstruction is: i miss and original is: i miss
# current loss is 1.3606628936574658 and jaccard is 52.28%
# reconstruction is: in spoke to you yesterday and u didnt respond girl wassup though! and original is: in spoke to you yesterday and u didnt respond girl wassup though!
# current loss is 1.3569681550065675 and jaccard is 52.36%
# reconstruction is: i love and original is: i love
# current loss is 1.3545717283926513 and jaccard is 52.54%
# reconstruction is: i guess it ` ll work under fusion. otherwise you ` ll have to boot directly to vista just to do some online banking, which sucks and original is: I guess it`ll work under fusion. Otherwise you`ll have to boot directly to Vista just to do some online banking, which sucks
# current loss is 1.352046723748321 and jaccard is 52.48%
# reconstruction is: who can do it like we? noboddddyyyy and original is: who can do it like we? Noboddddyyyy
# current loss is 1.350075542750182 and jaccard is 52.52%
# reconstruction is: hope the book is going well. cheers for adding me, and original is: Hope the book is going well. Cheers for adding me,
# current loss is 1.3474879793822765 and jaccard is 52.33%
# reconstruction is: dead. and original is: dead.
# current loss is 1.3450607171632947 and jaccard is 52.40%
# reconstruction is: cause i ` m not hearing from you guys!!! and original is: Cause I`m not hearing from you guys!!!
# current loss is 1.3425466540153477 and jaccard is 52.37%
# reconstruction is: has got the slow cooker going, now just to get ready for work and original is: Has got the slow cooker going, now just to get ready for work
# current loss is 1.3407786773949217 and jaccard is 52.64%
# reconstruction is: i was just watching some cartoons as i haven ` t in years when i was eating my breakfast, the programs have changed and original is: I was just watching some cartoons as I haven`t in years when I was eating my breakfast, the programs have changed
# current loss is 1.3384265536495616 and jaccard is 52.78%
# reconstruction is: [SEP] and original is: e lovely
# current loss is 1.3361590318899628 and jaccard is 52.60%
# reconstruction is: ok just a thought that occured to me... and original is: OK Just a thought that occured to me...
# current loss is 1.3357124288904836 and jaccard is 52.46%
# reconstruction is: i jus spoke 2 my lawyer, if i blow trial = 3to7 and original is: I jus spoke 2 my lawyer, if I blow trial =3to7
# current loss is 1.3318794072424616 and jaccard is 52.45%
# reconstruction is: probably going to miss silverstone ` s race again this season in iracing, so sad this track is pure laser scanned awesomeness and original is: probably going to miss Silverstone`s race again this season in iRacing , so sad this track is pure laser scanned awesomeness
# current loss is 1.3294938920024368 and jaccard is 52.53%
# reconstruction is: wiff and original is: wiff
# current loss is 1.3283420924729314 and jaccard is 52.55%
# reconstruction is: great and original is: great
# current loss is 1.3253474995779664 and jaccard is 52.49%
# reconstruction is: july 8th flight gets in, my mate here is on about goin hm early so am all and original is: july 8th flight gets in, my mate here is on about goin hm early so am all
# current loss is 1.3231679928627145 and jaccard is 52.59%
# reconstruction is: its like 2 in the morning.. sometimes i just don ` t know exactly what is best to do.. but i will def. figure it out!... happy moms day! and original is: its like 2 in the morning..sometimes I just don`t know exactly what is best to do..but I will def. figure it out! ...HAPPY MOMS DAY!
# current loss is 1.3203838369169751 and jaccard is 52.53%
# reconstruction is: !! people are so mean and original is: !! People are so mean
# current loss is 1.3186523925858056 and jaccard is 52.58%
# reconstruction is: i hate and original is: i hate
# current loss is 1.3162474176883698 and jaccard is 52.38%
# reconstruction is: one of my excellent designers and original is: One of my excellent designers
# current loss is 1.3138834193842301 and jaccard is 52.45%
# reconstruction is: having one of my bad days.. and original is: Having one of my bad days..
# current loss is 1.3115104552632884 and jaccard is 52.50%
# reconstruction is: it doesn ` t even have a scroll ball. and original is: it doesn`t even have a scroll ball.
# current loss is 1.3118500546224756 and jaccard is 52.31%
# reconstruction is: miss and original is: miss
# current loss is 1.3098536763485376 and jaccard is 52.57%
# reconstruction is: [SEP] and original is: One Thing I Hate About Friends An
# current loss is 1.307035306138377 and jaccard is 52.76%
# reconstruction is: i must have just missed you. i was down there until 9 : 40 or so. not sure if i ` ll make it down again and original is: i must have just missed you. I was down there until 9:40 or so. Not sure if I`ll make it down again
# current loss is 1.304039507745168 and jaccard is 52.74%
# reconstruction is: playing cards with my niece. and original is: Playing cards with my niece.
# current loss is 1.302037484000443 and jaccard is 52.87%
# reconstruction is: tired and original is: tired
# current loss is 1.2999002124010761 and jaccard is 52.96%
# reconstruction is: i missed you yesterday, lacey. we get to go to granulation tonight, though and original is: I missed you yesterday, Lacey. We get to go to granulation tonight, though
# current loss is 1.297893372549201 and jaccard is 52.95%
# reconstruction is: was hot! and original is: was hot!
# current loss is 1.2962141569927335 and jaccard is 52.89%
# reconstruction is: building websites and original is: Building Websites
# current loss is 1.2939196982813177 and jaccard is 53.03%
# reconstruction is: thanks and original is: Thanks
# current loss is 1.2931482667172396 and jaccard is 52.91%
# reconstruction is: wow. and original is: wow.
# current loss is 1.2900260384609363 and jaccard is 52.95%
# reconstruction is: what ` s good about working a double?... jasmin and original is: what`s good about working a double?...Jasmin
# current loss is 1.287629942123483 and jaccard is 53.03%
# reconstruction is: http : / / bit. ly / 13f5m0 you are not alone in your disbelief but i am quite happy with evolution. it beats the alternatives posited and original is: http://bit.ly/13f5m0 You are not alone in your disbelief but I am quite happy with evolution. It beats the alternatives posited
# current loss is 1.2859359430183064 and jaccard is 53.00%
# reconstruction is: wishes and original is: Wishes
# current loss is 1.2836758937390453 and jaccard is 53.21%
# reconstruction is: thank you and original is: Thank you
# current loss is 1.2811977598909847 and jaccard is 53.30%
# reconstruction is: talkshow with larry, then cage? and original is: talkshow with Larry, then Cage?
# current loss is 1.2787000439422471 and jaccard is 53.44%
# reconstruction is: avid fan of and original is: avid fan of
# current loss is 1.2777140543305663 and jaccard is 53.53%
# reconstruction is: my sister said yayyy its hannah hoedown today haaaa hannah is a hoe apparently hoe. and original is: my sister said yayyy its hannah HOEdown today haaaa hannah is a hoe apparently hoe.
# current loss is 1.2759006877085741 and jaccard is 53.59%
# reconstruction is: fail and original is: FAIL
# current loss is 1.2739018140829097 and jaccard is 53.52%
# reconstruction is: celebrating mothers ` day in 3 generations. and original is: celebrating mothers` day in 3 generations.
# current loss is 1.2729027724751207 and jaccard is 53.42%
# reconstruction is: well, of course the envelope i have for the book i need to mail is too small... if it had fit.... what fun would that be. and original is: Well, of course the envelope I have for the book I need to mail is too small...if it had fit....what fun would that be.
# current loss is 1.271118538979161 and jaccard is 53.49%
# reconstruction is: * smile and original is: *smile
# current loss is 1.2699277551968893 and jaccard is 53.28%
# reconstruction is: greastest hits and original is: Greastest Hits
# current loss is 1.2693149722371782 and jaccard is 53.30%
# reconstruction is: this is the end of the semester so i am really busy... have got no time for twitting what a pity cause i love it and original is: this is the end of the semester so i am really busy... have got no time for twitting what a pity cause i love it
# current loss is 1.2666647579317742 and jaccard is 53.34%
# reconstruction is: um k.. this is not close my eyes.. this song always makes me cry bc my mom is gone but i < 3 it anyway.. and original is: Um k.. this is NOT Close My Eyes.. this song always makes me cry bc my mom is gone but I <3 it anyway..
# current loss is 1.264819985621393 and jaccard is 53.48%
# reconstruction is: favourite and original is: favourite
# current loss is 1.2622474329726079 and jaccard is 53.39%
# reconstruction is: great to finally meet you last night! wish we had more time to talk. can ` t go to the coffee gtgs, though... day job. and original is: great to finally meet you last night! Wish we had more time to talk. Can`t go to the coffee GTGs, though... Day job.
# current loss is 1.2606665884316302 and jaccard is 53.31%
# reconstruction is: very long day and original is: very long day
# current loss is 1.2580439248747295 and jaccard is 53.23%
# reconstruction is: hello there? and original is: hello there ?
# current loss is 1.2558331220189511 and jaccard is 53.38%
# reconstruction is: yeah, i agree. it does. btw, check out! linuxoutlaws. ; ) and original is: Yeah, I agree. it does. BTW, check out !linuxoutlaws. ;)
# current loss is 1.2530931498650666 and jaccard is 53.35%
# reconstruction is: need to get a hand and original is: need to get a hand
# current loss is 1.2516945814369806 and jaccard is 53.55%
# reconstruction is: true and original is: true
# current loss is 1.251318366624739 and jaccard is 53.59%
# reconstruction is: _ uppercut that was such an ` old man ` thing to say and original is: _uppercut that was such an `old man` thing to say
# current loss is 1.2498919263465984 and jaccard is 53.57%
# reconstruction is: pretty much amazing. and original is: pretty much amazing.
# current loss is 1.2494912544565817 and jaccard is 53.62%
# reconstruction is: _ vip bye bye beard and original is: _vip bye bye beard
# current loss is 1.2473649984056299 and jaccard is 53.68%
# reconstruction is: aww and original is: aww
# current loss is 1.2461782765451899 and jaccard is 53.69%
# reconstruction is: [SEP] and original is: ) Hope you have a great ti
# current loss is 1.2439703615191122 and jaccard is 53.68%
# reconstruction is: worse and original is: worse
# current loss is 1.2432378896725804 and jaccard is 53.59%
# reconstruction is: i just watched my favorite movie'a walk to remember'its so romantic and sad i just love it and original is: I just watched my favorite movie 'A Walk to Remember' its so romantic and sad i just love it
# current loss is 1.2418495086100714 and jaccard is 53.80%
# reconstruction is: thanks, and original is: Thanks,
# current loss is 1.2403322272002697 and jaccard is 53.91%
# reconstruction is: can ` t you guys do something on co - op about grim fandango? don ` t you wanna see it on xbla / psn? call tony plana! call tim!! and original is: Can`t you guys do something on CO-OP about Grim Fandango? Don`t you wanna see it on XBLA/PSN? Call Tony Plana! Call Tim!!
# current loss is 1.239417257098954 and jaccard is 53.87%
# reconstruction is: depressing of course! ( kidding! ) i don ` t like the thought of my parents dying and original is: depressing of course! (KIDDING!) I don`t like the thought of my parents dying
# current loss is 1.2379814528681568 and jaccard is 53.94%
# reconstruction is: watching click, they are talkin about twitter and celebritytweet im just gonna get ready for work and original is: watching click, they are talkin about twitter and celebrityTweet im just gonna get ready for work
# current loss is 1.2372478496294754 and jaccard is 53.96%
# reconstruction is: i will and original is: i will
# current loss is 1.2357601182983846 and jaccard is 54.08%
# reconstruction is: * cough cough hack hack and original is: *cough cough hack hack
# current loss is 1.2345320866071634 and jaccard is 54.02%
# reconstruction is: fun and original is: fun
# current loss is 1.2333391720718807 and jaccard is 54.06%
# reconstruction is: microsoft has released zune also in europe, no hd for us and original is: Microsoft has released Zune also in Europe, no HD for us
# current loss is 1.2323879742083237 and jaccard is 54.20%
# reconstruction is: i accidentaly slammed my finger in the trunk and original is: I accidentaly slammed my finger in the trunk
# current loss is 1.231235822147131 and jaccard is 54.11%
# reconstruction is: ill in bed my stomach is killing me and original is: Ill in bed my stomach is killing me
# current loss is 1.2297136575369099 and jaccard is 54.34%
# reconstruction is: love and original is: love
# current loss is 1.228398259777834 and jaccard is 54.50%
# reconstruction is: dreary and original is: dreary
# current loss is 1.227213793852059 and jaccard is 54.51%
# reconstruction is: blogging - - http : / / 13tolife. us / mentioning links to contests where you might just win a free book or two! and original is: Blogging-- http://13tolife.us/ Mentioning links to contests where you might just win a free book or two!
# current loss is 1.2247520739015412 and jaccard is 54.50%
# reconstruction is: bloody and original is: bloody
# current loss is 1.2244416592586331 and jaccard is 54.44%
# reconstruction is: i feel some type of way cause im not talkin to anyone... and original is: i feel some type of way cause im not talkin to anyone...
# current loss is 1.2228341154276745 and jaccard is 54.47%
# reconstruction is: checkin out what new on twitter and original is: Checkin out what new on Twitter
# current loss is 1.2211990417374505 and jaccard is 54.53%
# reconstruction is: missed the play and original is: Missed the play
# current loss is 1.2204937441761676 and jaccard is 54.60%
# reconstruction is: killed and original is: killed
# current loss is 1.2196973972001144 and jaccard is 54.54%
# reconstruction is: happy and original is: Happy
# current loss is 1.2182112651211874 and jaccard is 54.61%
# reconstruction is: its sunny atm, need to drop my brother for his classes later, so will find out then and original is: Its sunny atm, need to drop my brother for his classes later, so will find out then
# current loss is 1.2171613266174262 and jaccard is 54.63%
# reconstruction is: it ` s killen me! and original is: It`s killen me!
# current loss is 1.2161348033063817 and jaccard is 54.58%
# reconstruction is: okay keep on celebreting and original is: Okay keep on celebreting
# current loss is 1.2143305876949024 and jaccard is 54.47%
# reconstruction is: those aren ` t even the old dolls... they are the new ones that look like sailor moon! and original is: those aren`t even the old dolls...they are the new ones that look like sailor moon!
# current loss is 1.2130402211608173 and jaccard is 54.54%
# reconstruction is: horrible! and original is: horrible!
# current loss is 1.2113198793156204 and jaccard is 54.69%
# reconstruction is: discouraged. and original is: discouraged.
# current loss is 1.2093585479314681 and jaccard is 54.71%
# reconstruction is: going to bed, with peter. and original is: Going to bed, with peter.
# current loss is 1.208194463027787 and jaccard is 54.87%
# reconstruction is: morning t! i love their breakfast! if i wasn ` t stuck at the shop right now getting maintenance done to the ride! and original is: morning T! I love their breakfast! If I wasn`t stuck at the shop right now getting maintenance done to the ride!
# current loss is 1.2073561218189537 and jaccard is 54.99%
# reconstruction is: actually i meant motorbike. not much touring, but i commute when possible - - about 90 min. roundtrip so it ` s kinda like touring and original is: actually I meant motorbike. Not much touring, but I commute when possible -- about 90 min. roundtrip so it`s kinda like touring
# current loss is 1.205500160978265 and jaccard is 55.14%
# reconstruction is: m bored and original is: m bored
# current loss is 1.2042808611122044 and jaccard is 55.21%
# reconstruction is: will continue my dramathon! episode 14 here i come! and original is: will continue my dramathon! episode 14 here i come!
# current loss is 1.2039520978981553 and jaccard is 55.24%
# reconstruction is: if someone had ` ve told me things would get this hard.. i would never have done it and original is: if someone had`ve told me things would get this hard..i would never have done it
# current loss is 1.2025222162566744 and jaccard is 55.21%
# reconstruction is: noooo i ` ll miss you too much! and original is: NOOOO I`ll miss you too much!
# current loss is 1.2010251111460373 and jaccard is 55.24%
# reconstruction is: shut your face! and original is: SHUT YOUR FACE!
# current loss is 1.2004416865802237 and jaccard is 55.20%
# reconstruction is: why not? its the most retarded thing someone could do at their 16th, and you know me - i like to be retarded. 8 ( and original is: why not? its the most retarded thing someone could do at their 16th, and you know me- I like to be retarded. 8(
# current loss is 1.1999301977740393 and jaccard is 55.10%
# reconstruction is: [SEP] and original is: s spoilt
# current loss is 1.1990785620961568 and jaccard is 55.05%
# reconstruction is: if i knew it was gonna be this kind of party, i would ` ve stuck my * * * * in the mashed potatoes! and original is: If I knew it was gonna be this kind of party, I would`ve stuck my **** in the mashed potatoes!
# current loss is 1.1975134338418818 and jaccard is 54.95%
# reconstruction is: i am very bummed that there are no babydoll or spaghetti - strap tank three wolf moon t - shirts. love the meme ; hate wearing a fabric box. and original is: I am very bummed that there are no babydoll or spaghetti-strap tank Three Wolf Moon t-shirts. Love the meme; hate wearing a fabric box.
# current loss is 1.1964307135395837 and jaccard is 55.04%
# reconstruction is: , i didn ` t which should probly mean i won ` t get it and original is: , I didn`t which should probly mean I won`t get it
# current loss is 1.1955866216467979 and jaccard is 55.00%
# reconstruction is: like it anyway, and original is: like it anyway,
# current loss is 1.1946782603004704 and jaccard is 54.93%
# reconstruction is: lost and original is: lost
# current loss is 1.1935282116792936 and jaccard is 54.94%
# reconstruction is: ooo growl and yummy time coming soon for you too huh oh yeah, i have been hunting for a combo tshirt, think i can find one? no and original is: ooo Growl and Yummy time coming soon for you too huh oh yeah, I have been hunting for a combo tshirt, think I can find one? NO
# current loss is 1.1929126908244758 and jaccard is 54.99%
# reconstruction is: da bomb u and original is: da bomb u
# current loss is 1.1922310719060283 and jaccard is 55.10%
# reconstruction is: . love 6th graders and original is: .love 6th graders
# current loss is 1.1911598042137603 and jaccard is 55.08%
# reconstruction is: still needs another 6 hours of sleep and original is: still needs another 6 hours of sleep
# current loss is 1.1907934364663795 and jaccard is 55.08%
# reconstruction is: a massive and original is: a massive
# current loss is 1.1900699161169892 and jaccard is 55.13%
# reconstruction is: [SEP] and original is: Wow. I hope he gets bette
# current loss is 1.1900312288753092 and jaccard is 55.00%
# reconstruction is: the girls looooved it! and original is: The girls LOOOOVED it!
# current loss is 1.1890538475643686 and jaccard is 54.99%
# reconstruction is: there is good cholesterol. there are no good tumors. and original is: There is good cholesterol. There are no good tumors.
# current loss is 1.1877746741292865 and jaccard is 55.02%
# reconstruction is: not a very good day at the house and original is: not a very good day at the house
# current loss is 1.1870044706414142 and jaccard is 55.03%
# reconstruction is: great! and original is: great!
# current loss is 1.1861758836819423 and jaccard is 55.03%
# reconstruction is: hope you don ` t get let down again. and original is: Hope you don`t get let down again.
# current loss is 1.1851169182101557 and jaccard is 55.10%
# reconstruction is: awful. and original is: awful.
# current loss is 1.1841942795559213 and jaccard is 55.01%
# reconstruction is: well done. and original is: Well done.
# current loss is 1.1831046383253863 and jaccard is 55.05%
# reconstruction is: with my jordie for a little bit and original is: With my jordie for a little bit
# current loss is 1.1825109157221658 and jaccard is 55.12%
# reconstruction is: yeah yeah? how the heck are you anyway? sastch it up again this year? i had to bail out for lack of expenses and original is: Yeah yeah? How the heck are you anyway? Sastch it up again this year? I had to bail out for lack of expenses
# current loss is 1.1818540303930034 and jaccard is 55.11%
# reconstruction is: _ control aw babyy i ` m sorry i gots too excited, haha. < 333 and original is: _control aw babyy i`m sorry i gots too excited, haha. <333
# current loss is 1.180752894651552 and jaccard is 55.16%
# I enjoyed enjoyed
# current validation loss is 0.8922117650508881 andjaccard score is 50.00%
# finishing off a quick magazine article for CAP, can`t wait to get it done and get back to the book finishing off a quick magazine article for cap, can ` t wait to get it done and get back to the book
# current validation loss is 0.8922117650508881 andjaccard score is 65.48%
# Delays/cancellations really bite. Have had my fair share and can sympathize. Hang tough delays / cancellations really bite. have had my fair share and can sympathize. hang tough!
# current validation loss is 0.8922117650508881 andjaccard score is 65.22%
# bonfires are my fave! fave!
# current validation loss is 0.8922117650508881 andjaccard score is 55.16%
# LOL watching Big Bang Theory latest episode lol watching big bang theory latest episode
# current validation loss is 0.844159586088998 andjaccard score is 64.13%
# i should of gone to kirsty`s for the night, anything to get out of the house i should of gone to kirsty ` s for the night, anything to get out of the house
# current validation loss is 0.844159586088998 andjaccard score is 65.94%
# Yeah that`s me I used my initials for my Flickr account! yeah that ` s me i used my initials for my flickr account!
# current validation loss is 0.844159586088998 andjaccard score is 66.41%
# e terrible terrible
# current validation loss is 0.844159586088998 andjaccard score is 64.36%
# _ladie haha, I`ve got my camera and lenses ready! _ ladie haha, i ` ve got my camera and lenses ready!
# current validation loss is 1.0986196051041286 andjaccard score is 62.77%
# got burnt up burnt
# current validation loss is 1.0986196051041286 andjaccard score is 59.82%
# ...than thank you....
# current validation loss is 1.0986196051041286 andjaccard score is 54.38%
# loves th loves
# current validation loss is 1.0986196051041286 andjaccard score is 54.02%
# what kind of party do we got going now? _ pooh what kind of party do we got going now?
# current validation loss is 0.9637307419496424 andjaccard score is 56.16%
# unfortunately unfortunately
# current validation loss is 0.9637307419496424 andjaccard score is 59.29%
# no one wants to watch it with me no one wants to watch it with me
# current validation loss is 0.9637307419496424 andjaccard score is 62.00%
# its been clownin since it got flooded in htown in april. Got it repaired or so I thought. its been clownin since it got flooded in htown in april. got it repaired or so i thought.
# current validation loss is 0.9637307419496424 andjaccard score is 64.38%
# yyyyuck! hurting
# current validation loss is 1.111550211906433 andjaccard score is 60.59%
# hope i hope
# current validation loss is 1.111550211906433 andjaccard score is 60.00%
# my sentiments exactly my sentiments exactly
# current validation loss is 1.111550211906433 andjaccard score is 62.11%
# ache ache
# current validation loss is 1.111550211906433 andjaccard score is 64.00%
# Happy happy
# current validation loss is 1.0758283999231126 andjaccard score is 65.72%
# well then take your sexy **** to sleep then foo. how as your weekend mami? well then take your sexy * * * * to sleep then foo. how as your weekend mami?
# current validation loss is 1.0758283999231126 andjaccard score is 66.63%
# No mine looks the same. no mine looks the same.
# current validation loss is 1.0758283999231126 andjaccard score is 68.08%
# The 'shhh..' stuff is finally all done! the'shhh..'stuff is finally all done!
# current validation loss is 1.0758283999231126 andjaccard score is 67.32%
# i love you i love you nicci!
# current validation loss is 1.0337192993611097 andjaccard score is 67.63%
# I hate my arrival i hate
# current validation loss is 1.0337192993611097 andjaccard score is 66.95%
# I gave him your kiss. Being a flirt of course he liked them liked them
# current validation loss is 1.0337192993611097 andjaccard score is 65.04%
# home=san diego, why did the san jose weather fallow me home = san diego, why did the san jose weather fallow me
# current validation loss is 1.0337192993611097 andjaccard score is 65.40%
# t`internet on blackberry fooked so no checking of the tweets and whether phill has taken up my request t ` internet on blackberry fooked so no checking of the tweets and whether phill has taken up my request
# current validation loss is 0.9530037142135002 andjaccard score is 65.93%
# she enjoyed it enjoyed it
# current validation loss is 0.9530037142135002 andjaccard score is 65.96%
# awesome. awesome..
# current validation loss is 0.9530037142135002 andjaccard score is 63.83%
# i was invited to one on the beach but it was too short notice i mean why the hell tell you 2hrs before?? really? i was invited to one on the beach but it was too short notice i mean why the hell tell you 2hrs before?? really?
# current validation loss is 0.9530037142135002 andjaccard score is 64.96%
# happy happy ish
# current validation loss is 0.9485011640049162 andjaccard score is 64.51%
# Want to get a Blackberry but can`t afford it . Just watching the telly and relaxing. Hard sesion tomorrow. hard
# current validation loss is 0.9485011640049162 andjaccard score is 62.77%
# Not to thrilled not to thrilled
# current validation loss is 0.9485011640049162 andjaccard score is 63.83%
# trying to decide what to do tonight. Study Chem or write the night away. The night`s still young, perhaps I`ll do both trying to decide what to do tonight. study chem or write the night away. the night ` s still young, perhaps i ` ll do both
# current validation loss is 0.9485011640049162 andjaccard score is 64.11%
# I know I think I`m like dieing! dieing!
# current validation loss is 0.9783154751392121 andjaccard score is 62.83%
# thanks for listening thanks
# current validation loss is 0.9783154751392121 andjaccard score is 62.05%
# soggy. all my pancakes always end up soggy.
# current validation loss is 0.9783154751392121 andjaccard score is 60.83%
# , to think their wives are nuts. nuts.
# current validation loss is 0.9783154751392121 andjaccard score is 59.66%
# I cried like a **** baby...I`m missing my beast like crazy! cried like a * * * * baby... i ` m missing my beast like crazy!
# current validation loss is 0.9909512606950907 andjaccard score is 59.60%
# Great you are all great americans!
# current validation loss is 0.9909512606950907 andjaccard score is 58.66%
# ...
# I hate working nights, cos I`m not really able to enjoy this gorgeous weather, as I will be asleep i hate
# current validation loss is 0.5257679349990998 andjaccard score is 71.27%
# Cheese Cake for my chweet mummy ! muaxxx cheese cake for my chweet mummy! muaxxx
# current validation loss is 0.5257679349990998 andjaccard score is 71.26%
# YAY! yay!
# current validation loss is 0.5258143824477896 andjaccard score is 71.27%
# but I don`t think I can get there i don ` t think i can get there
# current validation loss is 0.5258143824477896 andjaccard score is 71.27%
# _ yaaaay mish is following gab! _ yaaaay mish is following gab!
# current validation loss is 0.5258143824477896 andjaccard score is 71.27%
# trying to fix some weird query trying to fix some weird query
# current validation loss is 0.5258143824477896 andjaccard score is 71.28%
# id love to meet you, you`re my favourite comedian id love to meet you, you ` re my favourite comedian
# current validation loss is 0.5257126349027552 andjaccard score is 71.28%
# everybody is sick sick
# current validation loss is 0.5257126349027552 andjaccard score is 71.27%
# Missin my boo missin my boo
# current validation loss is 0.5257126349027552 andjaccard score is 71.28%
# wish wish
# current validation loss is 0.5257126349027552 andjaccard score is 71.28%
# I`m SUPER tired i ` m super tired
# current validation loss is 0.5257752627965856 andjaccard score is 71.27%
# cool looking sexy cool looking sexy
# current validation loss is 0.5257752627965856 andjaccard score is 71.28%
# Didn`t want it to end. didn ` t want it to end.
# current validation loss is 0.5257752627965856 andjaccard score is 71.28%
# thanx thanx
# current validation loss is 0.5257752627965856 andjaccard score is 71.28%
# found six great vegan places to eat and relax at; four of which I can`t get to without a car found six great vegan places to eat and relax at ; four of which i can ` t get to without a car
# current validation loss is 0.5255889836483685 andjaccard score is 71.28%
# Everyone is here. We`re off to party now everyone is here. we ` re off to party now
# current validation loss is 0.5255889836483685 andjaccard score is 71.28%
# but this little boy still makin me work during the storm!!! but this little boy still makin me work during the storm!!!
# current validation loss is 0.5255889836483685 andjaccard score is 71.29%
# you better come back soon! <3 you better come back soon! < 3
# current validation loss is 0.5255889836483685 andjaccard score is 71.28%
# friday.....i have nothing to do so sad sad
# current validation loss is 0.5255260478188772 andjaccard score is 71.27%
# Thanks, thanks,
# current validation loss is 0.5255260478188772 andjaccard score is 71.28%
# sorry sorry
# current validation loss is 0.5255260478188772 andjaccard score is 71.28%
# very frustrated th frustrated
# current validation loss is 0.5255260478188772 andjaccard score is 71.28%
# just did my bit to stimulate the economy just did my bit to stimulate the economy
# current validation loss is 0.5255606319406837 andjaccard score is 71.28%
# sick. sick.
# current validation loss is 0.5255606319406837 andjaccard score is 71.29%
# bummed bummed
# current validation loss is 0.5255606319406837 andjaccard score is 71.29%
# loving loving
# current validation loss is 0.5255606319406837 andjaccard score is 71.30%
# good luck to them good luck to them
# current validation loss is 0.5256044859210971 andjaccard score is 71.31%
# poor poor
# current validation loss is 0.5256044859210971 andjaccard score is 71.31%
# _carter it says the video is private... and won`t let me watch _ carter it says the video is private... and won ` t let me watch
# current validation loss is 0.5256044859210971 andjaccard score is 71.31%
# ****.. * * * *..
# current validation loss is 0.5256044859210971 andjaccard score is 71.29%
# i can`t see results for whyareyoustillhere i can ` t see results for whyareyoustillhere
# current validation loss is 0.5256318544888724 andjaccard score is 71.29%
# argh. Interested. argh. interested. time maybe can ` t go. maybe.
# current validation loss is 0.5256318544888724 andjaccard score is 71.28%
# im sad you didnt text today. im sad
# current validation loss is 0.5256318544888724 andjaccard score is 71.27%
# Lookin forward to lookin forward to
# current validation loss is 0.5256318544888724 andjaccard score is 71.28%
# g happier that`ll make you feel better aww sweetie you could always take a break and read or write something happier that ` ll make you feel better
# current validation loss is 0.525552081708272 andjaccard score is 71.27%
# hahaha my uncle does that coz my aunty is a **** who left her kids hahaha my uncle does that coz my aunty is a * * * * who left her kids
# current validation loss is 0.525552081708272 andjaccard score is 71.27%
# cute. cute..
# current validation loss is 0.525552081708272 andjaccard score is 71.26%
# Good times good times
# current validation loss is 0.525552081708272 andjaccard score is 71.26%
# yay me yay me
# current validation loss is 0.5254331703541785 andjaccard score is 71.27%
# Good morning!! good
# current validation loss is 0.5254331703541785 andjaccard score is 71.26%
# sigh) sigh )
# current validation loss is 0.5254331703541785 andjaccard score is 71.25%
# I ran over a turtle. i ran over a turtle.
# current validation loss is 0.5254331703541785 andjaccard score is 71.26%
# Just touched down in Changi. +1/2 hrs to kill before heading to Penang. Must fly singapore air more often! just touched down in changi. + 1 / 2 hrs to kill before heading to penang. must fly singapore air more often!
# current validation loss is 0.5253069398783261 andjaccard score is 71.26%
# o slap slap girls icky * * * * encoraging bad behavior
# current validation loss is 0.5253069398783261 andjaccard score is 71.25%
# I should be DJing my prom! I`d do it for free...there prob gonna have a dj who`s stuck in the 80`s boooooo i should be djing my prom! i ` d do it for free... there prob gonna have a dj who ` s stuck in the 80 ` s boooooo
# current validation loss is 0.5253069398783261 andjaccard score is 71.24%
# hopefully hopefully
# current validation loss is 0.5253069398783261 andjaccard score is 71.25%
# e sad aw were sad
# current validation loss is 0.5254127296638348 andjaccard score is 71.24%
# I have to call stevie to reschedule!! I won a competition yesterday to the launch of sims 3 at Luna park, same day at 6pm i have to call stevie to reschedule!! i won a competition yesterday to the launch of sims 3 at luna park, same day at 6pm
# current validation loss is 0.5254127296638348 andjaccard score is 71.25%
# i dont wanna go back to school on monday :`( enjoying the hot weatler lo0l ;) im well bored had a great half term and i dont wanna go back to school on monday : ` ( enjoying the hot weatler lo0l ; )
# current validation loss is 0.5254127296638348 andjaccard score is 71.24%
# so what cereal do you usually like? so what cereal do you usually like?
# current validation loss is 0.5254127296638348 andjaccard score is 71.25%
# Yay! yay!
# current validation loss is 0.5252622227944386 andjaccard score is 71.25%
# im seeing this guy 2moro arvo after skl cus he asked me to im seeing this guy 2moro arvo after skl cus he asked me to
# current validation loss is 0.5252622227944386 andjaccard score is 71.26%
# That`s just not right. that ` s just not right.
# current validation loss is 0.5252622227944386 andjaccard score is 71.25%
# sorry about your sadness sadness
# current validation loss is 0.5252622227944386 andjaccard score is 71.24%
# Those suck so bad. those suck so bad.
# current validation loss is 0.5252307380661758 andjaccard score is 71.25%
# great, great,
# current validation loss is 0.5252307380661758 andjaccard score is 71.25%
# _Jolene Try 90 4 next 3 days! :O Yuk! lol n e thing poppin` @ _ jolene try 90 4 next 3 days! : o yuk! lol n e thing poppin ` @
# current validation loss is 0.5252307380661758 andjaccard score is 71.25%
# lol i hope i find someone to give me one too! lol lol i hope i find someone to give me one too! lol
# current validation loss is 0.5252307380661758 andjaccard score is 71.26%
# i wanna go home i wanna go home
# current validation loss is 0.5251958183706713 andjaccard score is 71.26%
# love em love em
# current validation loss is 0.5251958183706713 andjaccard score is 71.27%
# Thank you thank you
# current validation loss is 0.5251958183706713 andjaccard score is 71.28%
# The rest of the week is less than 2.5 hours long the rest of the week is less than 2. 5 hours long
# current validation loss is 0.5251958183706713 andjaccard score is 71.28%
# go dreambears <33333 hahahahaha hahahahaha
# current validation loss is 0.5253858134778486 andjaccard score is 71.27%
# love yo happy hug your mom day!! love you mom
# current validation loss is 0.5253858134778486 andjaccard score is 71.25%
# virus. virus.
# current validation loss is 0.5253858134778486 andjaccard score is 71.26%
# had a wonderful evening with those I love! wonderful evening with those i love!
# current validation loss is 0.5253858134778486 andjaccard score is 71.26%
# better better
# current validation loss is 0.5252701790478328 andjaccard score is 71.27%
# Cant fall asleep. cant fall asleep.
# current validation loss is 0.5252701790478328 andjaccard score is 71.27%
# Cute cute name.
# current validation loss is 0.5252701790478328 andjaccard score is 71.27%
# t thatwouldmake1of myFRIENDS happy happy
# current validation loss is 0.5252701790478328 andjaccard score is 71.26%
# we can`t wait to see you we can ` t wait to see you
# current validation loss is 0.5252740715629745 andjaccard score is 71.26%
# You should try it. It`s the way of The Deena you should try it. it ` s the way of the deena
# current validation loss is 0.5252740715629745 andjaccard score is 71.26%
# Excited about having an empty apartment to ourselves for a little while excited about having an empty apartment to ourselves for a little while
# current validation loss is 0.5252740715629745 andjaccard score is 71.26%
# lovel lovely
# current validation loss is 0.5252740715629745 andjaccard score is 71.25%
# sad sad
# current validation loss is 0.5253524707382309 andjaccard score is 71.25%
# scarred for life! scarred for life!
# current validation loss is 0.5253524707382309 andjaccard score is 71.26%
# Woke up.. Walked out of my room, and a bug flew in my eye woke up.. walked out of my room, and a bug flew in my eye
# current validation loss is 0.5253524707382309 andjaccard score is 71.26%
# **** * * * *
# current validation loss is 0.5253524707382309 andjaccard score is 71.25%
# nice nice
# current validation loss is 0.5252951127636204 andjaccard score is 71.26%
# wish I could alter time!! wish i could alter time!! *
# current validation loss is 0.5252951127636204 andjaccard score is 71.26%
# Dany, meet Sorcha, Sorcha, Dany. Now you know each other. :- dany, meet sorcha, sorcha, dany. now you know each other. : - p
# current validation loss is 0.5252951127636204 andjaccard score is 71.26%
# just wants to hear his voice just wants to hear his voice
# current validation loss is 0.5252951127636204 andjaccard score is 71.26%
# YAY yay
# current validation loss is 0.52531833566358 andjaccard score is 71.27%
# AHhh FCUKKK...i missed out AGAIN ahhh fcukkk... i missed out again
# current validation loss is 0.52531833566358 andjaccard score is 71.27%
# Suspend working again, fewer mem leaks suspend working again, fewer mem leaks
# current validation loss is 0.52531833566358 andjaccard score is 71.27%
# Now I have no SKy until Monday now i have no sky until monday
# current validation loss is 0.52531833566358 andjaccard score is 71.28%
# loving th loving
# current validation loss is 0.5252108647886504 andjaccard score is 71.27%
# cool yay emily i m cool
# current validation loss is 0.5252108647886504 andjaccard score is 71.26%
# Time flies...and i never got it all right. Why oh why? time flies... and i never got it all right. why oh why?
# current validation loss is 0.5252108647886504 andjaccard score is 71.26%
# congradts on ur show Even tho i wasnt there lol congradts on ur show even tho i wasnt there lol
# current validation loss is 0.5252108647886504 andjaccard score is 71.27%
# Such a pretty baby! such a pretty baby!
# current validation loss is 0.5251863043678452 andjaccard score is 71.28%
# I can understand! i can understand!
# current validation loss is 0.5251863043678452 andjaccard score is 71.28%
# im almost to 300 updates. 200 more to goo im almost to 300 updates. 200 more to goo
# current validation loss is 0.5251863043678452 andjaccard score is 71.29%
# Missed missed
# current validation loss is 0.5251863043678452 andjaccard score is 71.29%
# will do it in a couple od days , when I have more time., for now I need to get some sleep. Night Night All. Pe will do it in a couple od days, when i have more time., for now i need to get some sleep. night night all. peace.!!!!
# current validation loss is 0.5253006244094601 andjaccard score is 71.30%
# where u at? where u at?
# current validation loss is 0.5253006244094601 andjaccard score is 71.30%
# gotta play `Off the Wall` first tho gotta play ` off the wall ` first tho
# current validation loss is 0.5253006244094601 andjaccard score is 71.30%
# Doctors don`t get sick! hope you get well soo what happened?... doctors don ` t get sick! hope you get well soon...
# current validation loss is 0.5253006244094601 andjaccard score is 71.29%
# Sry I missed your calls. I fell asleep out of boredom. Colorado Sunrise was enjoyable though. I actually could hear it. xD sry i missed your calls. i fell asleep out of boredom. colorado sunrise was enjoyable though. i actually could hear it. xd
# current validation loss is 0.5252290251325784 andjaccard score is 71.30%
# Its so obvious Holly will go thru on the public vote straight away.. SOOO obvious. Then Aidan and Greg for judges but neither should go its so obvious holly will go thru on the public vote straight away.. sooo obvious. then aidan and greg for judges but neither should go
# current validation loss is 0.5252290251325784 andjaccard score is 71.30%
# no fun! no fun!
# current validation loss is 0.5252290251325784 andjaccard score is 71.31%
# no problem. i wasn`t really sure what i was doing. it was some application on the twibe page. no problem. i wasn ` t really sure what i was doing. it was some application on the twibe page.
# current validation loss is 0.5252290251325784 andjaccard score is 71.31%
# Oh, so no male strippers then? LMAO oh, so no male strippers then? lmao
# current validation loss is 0.525195394211092 andjaccard score is 71.32%
# was amazin! amazin!
# current validation loss is 0.525195394211092 andjaccard score is 71.31%
# gooooooooood gooooooooood
# current validation loss is 0.525195394211092 andjaccard score is 71.32%
# you got your lion hoodie!! mines still a week or so away what number is yours? you got your lion hoodie!! mines still a week or so away what number is yours?
# current validation loss is 0.525195394211092 andjaccard score is 71.32%
# BOYSTOWN. I`ll leave for Eastwood in 3hours. boystown. i ` ll leave for eastwood in 3hours.
# current validation loss is 0.5250445248790403 andjaccard score is 71.32%
# Trouble in paradice trouble in paradice
# current validation loss is 0.5250445248790403 andjaccard score is 71.33%
# hanging out with Dan and Brian in my room for my last night hanging out with dan and brian in my room for my last night
# current validation loss is 0.5250445248790403 andjaccard score is 71.33%
# saaaaaaaaaaaaaad im saaaaaaaaaaaaaad
# current validation loss is 0.5250445248790403 andjaccard score is 71.33%
# Thanks thanks so much
# current validation loss is 0.5252754063725433 andjaccard score is 71.32%
# where did the rain go?? where did the rain go??
# current validation loss is 0.5252754063725433 andjaccard score is 71.33%
# Thinks she`s getting sick..... sick..
# current validation loss is 0.5252754063725433 andjaccard score is 71.31%
# who loves his mum loving, caring ` soul - full ` man - who loves his mum
# current validation loss is 0.5252754063725433 andjaccard score is 71.30%
# For epoch 3 training loss is 0.714309660645243,         training accuracy is 64.46%, Validation         loss is 0.5252581576005012 and validation accuracy is 71.30%
# saving the model with jac_acc  71.30%

# %%
# test
max_seq_length = 180

class Tweet_Loader_Test(object):
    '''
    1. tokenize the text
    2. find the indices of the selected text in the original text
    3. append the question to the original text and modify original indexes
    4. identify start index and end index
    5. identify start and end index
    '''

    def __init__(self, text, sentiment, textID):
        
        # define the text column from the dataframe
        self.text_column = text.tolist()
    
        # define sentiment
        self.sentinent = sentiment.tolist()
                   
        # define the label column and transform it to list
        self.textID = textID.tolist()
        
    # iter method to get each element at the time and tokenize it using bert        
    def __getitem__(self, index):
        
        sentinent = self.sentinent[index]
        text_id = self.textID[index]
        text = self.text_column[index]
        text = " ".join(str(text).split())
        
        # get tokenized text
        tokenized_text = tokenizer.tokenize(text)
        
                
        # use the encode plus function
        dictionary_inputs = tokenizer.encode_plus(sentinent, text, 
                                                  max_length = max_seq_length,
                                                  #truncation_strategy  ='do_not_truncate', 
                                                  add_special_tokens = True,
                                                  pad_to_max_length = True, padding_side='Right', 
                                                  is_pretokenized = False, return_token_type_ids=True,
                                                  return_attention_mask=True,
                                                  return_offsets_mapping = True,
                                                  return_tensors = 'pt')
        
        return [dictionary_inputs, text_id]
  
    def __len__(self):
        return len(self.text_column)

# %%
# create a class to process the traininga and test data
batch_size = 4
test_data = Tweet_Loader_Test(test['text'],test['sentiment'], test['textID'])

# use the dataloaders class to load the data
dataloaders_dict_test = {'test': DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=4)}

dataset_sizes = {'test':len(test_data)}

# %%
def predictions(model = None):
    prediction_data_frame_list = []
    
    with torch.no_grad():
        model.eval()
        
        for i, (dict_param, tweet_id) in enumerate(dataloaders_dict_test['test']):
            # add a counter that will register how many examples we have fed to the
            # model
            # move the sequences, labels and masks to the GPU
                inputs = dict_param.get('input_ids').to(device).squeeze()
                token_type_ids = dict_param.get('token_type_ids').to(device).squeeze()
                attention_mask = dict_param.get('attention_mask').to(device).squeeze()

            # feed the sequences to the model, specifying the attention mask
                start_scores, end_scores = model(inputs, token_type_ids = token_type_ids, 
                                                   attention_mask = attention_mask)
            
                start_preds=torch.argmax(start_scores,dim=1).cpu().detach().numpy()
                end_preds=torch.argmax(end_scores,dim=1).cpu().detach().numpy()
                inputs = inputs.cpu().detach().numpy()
                
                for i in range(inputs.shape[0]):
                    a = tweet_id[i]
                    pred_string = reconstruct_string(start_preds[i], end_preds[i], inputs[i])
                    #pred_string = pred_string.replace(' ##', '')
                    print(f'the id is {a} and the string is {pred_string}')
                                        
                    temp_data = pd.DataFrame(zip([a],[pred_string]), columns = ['textID', 'selected_text'])
                    print(temp_data.head())
                    prediction_data_frame_list.append(temp_data)                
    
    prediction_df = pd.concat(prediction_data_frame_list)
    return prediction_df

# %%
model.load_state_dict(torch.load('../models_trained/bert_tweet_extraction_no_finetuned.pth'))
# Out:
# <All keys matched successfully>

# %%
prediction = predictions(model)
# Out:
# the id is f87dea47db and the string is last session of the day
#        textID            selected_text
# 0  f87dea47db  last session of the day
# the id is 96d74cb729 and the string is good tweeps
#        textID selected_text
# 0  96d74cb729   good tweeps
# the id is eee518ae67 and the string is shame!
#        textID selected_text
# 0  eee518ae67        shame!
# the id is 01082688c6 and the string is happy bday!
#        textID selected_text
# 0  01082688c6   happy bday!
# the id is 33987a8ee5 and the string is i like it!!
#        textID selected_text
# 0  33987a8ee5   i like it!!
# the id is 726e501993 and the string is that ` s great!
#        textID    selected_text
# 0  726e501993  that ` s great!
# the id is 261932614e and the string is hates
#        textID selected_text
# 0  261932614e         hates
# the id is afa11da83f and the string is blocked
#        textID selected_text
# 0  afa11da83f       blocked
# the id is e64208b4ef and the string is and within a short time of the last clue all of them
#        textID                                      selected_text
# 0  e64208b4ef  and within a short time of the last clue all o...
# the id is 37bcad24ca and the string is what did you get? my day is alright.. haven ` t done anything yet. leaving soon to my stepsister though!
#        textID                                      selected_text
# 0  37bcad24ca  what did you get? my day is alright.. haven ` ...
# the id is 24c92644a4 and the string is argh total bummer
#        textID      selected_text
# 0  24c92644a4  argh total bummer
# the id is 43b390b336 and the string is i checked. we didn ` t win
#        textID               selected_text
# 0  43b390b336  i checked. we didn ` t win
# the id is 69d6b5d93e and the string is .. and you ` re on twitter! did the tavern bore you that much?
#        textID                                      selected_text
# 0  69d6b5d93e  .. and you ` re on twitter! did the tavern bor...
# the id is 5c1e0b61a1 and the string is sad,
#        textID selected_text
# 0  5c1e0b61a1          sad,
# the id is 504e45d9d9 and the string is its coming out the socket i feel like my phones hole is not a virgin.
#        textID                                      selected_text
# 0  504e45d9d9  its coming out the socket i feel like my phone...
# the id is ae93ad52a0 and the string is hate my new timetable, having such a bad week
#        textID                                  selected_text
# 0  ae93ad52a0  hate my new timetable, having such a bad week
# the id is 9fce30159a and the string is miss you
#        textID selected_text
# 0  9fce30159a      miss you
# the id is 00d5195223 and the string is cramps...
#        textID selected_text
# 0  00d5195223     cramps...
# the id is 33f19050cf and the string is nice
#        textID selected_text
# 0  33f19050cf          nice
# the id is f7718b3c23 and the string is i ` m going into a spiritual stagnentation, its exploding my ego!. i now realise, i ` m not all that great. and i ` m ok with that.
#        textID                                      selected_text
# 0  f7718b3c23  i ` m going into a spiritual stagnentation, it...
# the id is 9ef44428d0 and the string is stupid
#        textID selected_text
# 0  9ef44428d0        stupid
# the id is be634ebeb0 and the string is dead
#        textID selected_text
# 0  be634ebeb0          dead
# the id is 3dcf4f7e13 and the string is bad.
#        textID selected_text
# 0  3dcf4f7e13          bad.
# the id is f0ef04109b and the string is about to go to sleep
#        textID         selected_text
# 0  f0ef04109b  about to go to sleep
# the id is 8be365118e and the string is you are lame
#        textID selected_text
# 0  8be365118e  you are lame
# the id is c50bdd4567 and the string is thats so cool
#        textID  selected_text
# 0  c50bdd4567  thats so cool
# the id is 334954f215 and the string is hey peoples, dont you just hate being grounded haha, im just sat eating an apple and watching death note ( some anime )
#        textID                                      selected_text
# 0  334954f215  hey peoples, dont you just hate being grounded...
# the id is b783916431 and the string is huh, another scarepoint coding sunday
#        textID                          selected_text
# 0  b783916431  huh, another scarepoint coding sunday
# the id is 1fa8e6ad66 and the string is
#        textID selected_text
# 0  1fa8e6ad66
# the id is be38b29042 and the string is sweating it out on a hot humid day
#        textID                       selected_text
# 0  be38b29042  sweating it out on a hot humid day
# the id is 95701e8ed9 and the string is guess that depends on if you want to be on the jury
#        textID                                      selected_text
# 0  95701e8ed9  guess that depends on if you want to be on the...
# the id is 4dd58ecd2c and the string is resorted to eating mickey ds alone.
#        textID                        selected_text
# 0  4dd58ecd2c  resorted to eating mickey ds alone.
# the id is cf553cccd5 and the string is there is a faux gothy chick looking at me, sorry i am not going to camden and i like pop - punk and jimmy eat world
#        textID                                      selected_text
# 0  cf553cccd5  there is a faux gothy chick looking at me, sor...
# the id is 55c69c2d52 and the string is did he ask for your twitter id? your sun sign?
#        textID                                   selected_text
# 0  55c69c2d52  did he ask for your twitter id? your sun sign?
# the id is 9b1a52cc02 and the string is where ` d you go!
#        textID      selected_text
# 0  9b1a52cc02  where ` d you go!
# the id is cce5c4744a and the string is good film
#        textID selected_text
# 0  cce5c4744a     good film
# the id is c7f9d559e2 and the string is happy
#        textID selected_text
# 0  c7f9d559e2         happy
# the id is 3d2478db59 and the string is so i really need to put the laptop down & start getting ready for shindig... but i ` ve missed my twitterloves all day
#        textID                                      selected_text
# 0  3d2478db59  so i really need to put the laptop down & star...
# the id is 6d846d7d50 and the string is i ` m sorry
#        textID selected_text
# 0  6d846d7d50   i ` m sorry
# the id is 599f51af6b and the string is feels sorry
#        textID selected_text
# 0  599f51af6b   feels sorry
# the id is 87daa62920 and the string is never heard of it esti beat acum? u tweet too much
#        textID                                      selected_text
# 0  87daa62920  never heard of it esti beat acum? u tweet too ...
# the id is 6506dc55ff and the string is i always forget something when i travel. i am at newark airport.
#        textID                                      selected_text
# 0  6506dc55ff  i always forget something when i travel. i am ...
# the id is 746d87f93e and the string is should have left car and walked home! i might need someone to rescue me with petrol! light flashing
#        textID                                      selected_text
# 0  746d87f93e  should have left car and walked home! i might ...
# the id is ef7ef8e474 and the string is i ` m only updating this so that brett ` s phone beeps but really.. looking at wedding stuff. again. for the next five months.
#        textID                                      selected_text
# 0  ef7ef8e474  i ` m only updating this so that brett ` s pho...
# the id is d3d7b13278 and the string is happy, not breaking down in tears
#        textID                      selected_text
# 0  d3d7b13278  happy, not breaking down in tears
# the id is ddc07db84e and the string is hope ur havin fun
#        textID      selected_text
# 0  ddc07db84e  hope ur havin fun
# the id is 67afe60d31 and the string is i miss my old phone it worked so good until i dropped it i want a new one for my birthday...
#        textID                                      selected_text
# 0  67afe60d31  i miss my old phone it worked so good until i ...
# the id is 17d18ba9ef and the string is wonderful
#        textID selected_text
# 0  17d18ba9ef     wonderful
# the id is ab57d75f20 and the string is sorry i know wallah how u feel this life is shittttttttt
#        textID                                      selected_text
# 0  ab57d75f20  sorry i know wallah how u feel this life is sh...
# the id is f0acd25d8e and the string is not happy
#        textID selected_text
# 0  f0acd25d8e     not happy
# the id is cf3b068b03 and the string is is watching acoustic performances! & in the mood for a good'friends'episode! i miss that show
#        textID                                      selected_text
# 0  cf3b068b03  is watching acoustic performances! & in the mo...
# the id is d6c34fa875 and the string is i ` ll oscillate from one to the other.
#        textID                            selected_text
# 0  d6c34fa875  i ` ll oscillate from one to the other.
# the id is 614aed9113 and the string is tired..
#        textID selected_text
# 0  614aed9113       tired..
# the id is dfa577d3c1 and the string is thanks
#        textID selected_text
# 0  dfa577d3c1        thanks
# the id is 10dcbe4dfb and the string is you should totally come get me and bring me to kelslaws house with you.
#        textID                                      selected_text
# 0  10dcbe4dfb  you should totally come get me and bring me to...
# the id is a0bfb12773 and the string is you seem nice,
#        textID   selected_text
# 0  a0bfb12773  you seem nice,
# the id is 71f4a9b495 and the string is u so dirrrrrty... why oh why did i pick the hawks i figured i needed a longshot and they were a better bet than car
#        textID                                      selected_text
# 0  71f4a9b495  u so dirrrrrty... why oh why did i pick the ha...
# the id is d33ed264b3 and the string is almost got a kitty yesterday... but it didn ` t work out
#        textID                                      selected_text
# 0  d33ed264b3  almost got a kitty yesterday... but it didn ` ...
# the id is 77f88ea9e2 and the string is reality needs to check in. schools over. time to party not tonight tho, im going to bed. night, night.
#        textID                                      selected_text
# 0  77f88ea9e2  reality needs to check in. schools over. time ...
# the id is fe1deac869 and the string is nice peaceful
#        textID  selected_text
# 0  fe1deac869  nice peaceful
# the id is e591a725ef and the string is i still dont know what we would do though
#        textID                              selected_text
# 0  e591a725ef  i still dont know what we would do though
# the id is 2dbb28cc29 and the string is _ xo dang it, so its not certain??? are you okay?
#        textID                                      selected_text
# 0  2dbb28cc29  _ xo dang it, so its not certain??? are you okay?
# the id is a7e4ad250a and the string is change of plans. i am staying in brandon. no papaya salad for me.
#        textID                                      selected_text
# 0  a7e4ad250a  change of plans. i am staying in brandon. no p...
# the id is 7d87899024 and the string is suck.
#        textID selected_text
# 0  7d87899024         suck.
# the id is 461b51fa58 and the string is at starbucks with my love. eff school. i have work later too.
#        textID                                      selected_text
# 0  461b51fa58  at starbucks with my love. eff school. i have ...
# the id is c31d79c440 and the string is cried
#        textID selected_text
# 0  c31d79c440         cried
# the id is 32ee7ef6c2 and the string is looking forward
#        textID    selected_text
# 0  32ee7ef6c2  looking forward
# the id is 29f805a7d2 and the string is terminator salvation... by myself.
#        textID                       selected_text
# 0  29f805a7d2  terminator salvation... by myself.
# the id is d41fe360e4 and the string is dumbface... him, not u. what u up to on the wknd? i wanna seeeeeee ya!
#        textID                                      selected_text
# 0  d41fe360e4  dumbface... him, not u. what u up to on the wk...
# the id is a04c8c8695 and the string is why do i have to enter my registration details every time i update?
#        textID                                      selected_text
# 0  a04c8c8695  why do i have to enter my registration details...
# the id is 25e42b2bf2 and the string is i love you
#        textID selected_text
# 0  25e42b2bf2    i love you
# the id is 5843d17b1d and the string is cute..
#        textID selected_text
# 0  5843d17b1d        cute..
# the id is 474d10ff48 and the string is tgif is right... i think i broke my toe last night - on my bad foot.
#        textID                                      selected_text
# 0  474d10ff48  tgif is right... i think i broke my toe last n...
# the id is 38e69da3a1 and the string is oherr it ` s soon then, do you have plans? i had a party on saturday x
#        textID                                      selected_text
# 0  38e69da3a1  oherr it ` s soon then, do you have plans? i h...
# the id is 972dc5787d and the string is very young looking dude
#        textID            selected_text
# 0  972dc5787d  very young looking dude
# the id is 0ba6aaf9aa and the string is wrong link, ignore my tweet
#        textID                selected_text
# 0  0ba6aaf9aa  wrong link, ignore my tweet
# the id is 7a81537034 and the string is cheated
#        textID selected_text
# 0  7a81537034       cheated
# the id is 311d2b185b and the string is breaks my achy breaky heart
#        textID                selected_text
# 0  311d2b185b  breaks my achy breaky heart
# the id is 1e46d72ec6 and the string is wish
#        textID selected_text
# 0  1e46d72ec6          wish
# the id is 390f169584 and the string is im a lady and ladies don ` t move couches. they direct where the couches go
#        textID                                      selected_text
# 0  390f169584  im a lady and ladies don ` t move couches. the...
# the id is 58129e4130 and the string is thanks for supporting nkotb!
#        textID                 selected_text
# 0  58129e4130  thanks for supporting nkotb!
# the id is e6c9e5e3ab and the string is 26th february
#        textID  selected_text
# 0  e6c9e5e3ab  26th february
# the id is cb5e709de8 and the string is guess what? mom adopted a kitty today ( 11 months ) his name is corky
#        textID                                      selected_text
# 0  cb5e709de8  guess what? mom adopted a kitty today ( 11 mon...
# the id is a14b4ff440 and the string is happy birthday snickers!!!!? i hope you have the best
#        textID                                      selected_text
# 0  a14b4ff440  happy birthday snickers!!!!? i hope you have t...
# the id is 5d57a5eda2 and the string is thank you!
#        textID selected_text
# 0  5d57a5eda2    thank you!
# the id is 1e3561e921 and the string is lol man i got 2 1 / 2 hrs an iont how i woulda made it wit out my ramen noodles and t. v. time
#        textID                                      selected_text
# 0  1e3561e921  lol man i got 2 1 / 2 hrs an iont how i woulda...
# the id is c2ea5cb58b and the string is not feeling all that well today
#        textID                    selected_text
# 0  c2ea5cb58b  not feeling all that well today
# the id is cde0016d6d and the string is my ear hurts,
#        textID  selected_text
# 0  cde0016d6d  my ear hurts,
# the id is 5fc411e8d1 and the string is _ berland lmao i know i know
#        textID                 selected_text
# 0  5fc411e8d1  _ berland lmao i know i know
# the id is 5ffb19ae8f and the string is gnight shar < ( ` ` < ) vega ( > ` ` ) >
#        textID                             selected_text
# 0  5ffb19ae8f  gnight shar < ( ` ` < ) vega ( > ` ` ) >
# the id is 76da985a47 and the string is poking me in the armpit
#        textID            selected_text
# 0  76da985a47  poking me in the armpit
# the id is 3a98aa4762 and the string is happy mothers day!!!
#        textID         selected_text
# 0  3a98aa4762  happy mothers day!!!
# the id is 886545bbab and the string is yes, i am
#        textID selected_text
# 0  886545bbab     yes, i am
# the id is 2afe118dc3 and the string is i can ` t call mitch! im from sweden!
#        textID                          selected_text
# 0  2afe118dc3  i can ` t call mitch! im from sweden!
# the id is 704c53f4cf and the string is happy star wars day! may the fourth be with you
#        textID                                    selected_text
# 0  704c53f4cf  happy star wars day! may the fourth be with you
# the id is 71fa60d9ff and the string is was so excited to eat the wartermelon i bought the other day and it was terrible and not sweet
#        textID                                      selected_text
# 0  71fa60d9ff  was so excited to eat the wartermelon i bought...
# the id is c238c4dbb7 and the string is cried so hard!
#        textID   selected_text
# 0  c238c4dbb7  cried so hard!
# the id is dc73e85417 and the string is take antibacterial to school to clean your hands when you cant go the loos
#        textID                                      selected_text
# 0  dc73e85417  take antibacterial to school to clean your han...
# the id is af63915fa9 and the string is i ` m leaving work now. trying to decide if i return on sunday afternoon or monday 4 am to meet a noon ( uk time ) deadline.
#        textID                                      selected_text
# 0  af63915fa9  i ` m leaving work now. trying to decide if i ...
# the id is eb2fc4d281 and the string is hope i make it
#        textID   selected_text
# 0  eb2fc4d281  hope i make it
# the id is f9382a1f7b and the string is oooh, sunshine! a patch of sunshine! and it will be gone by the time i leave work and replaced with rain. / vent
#        textID                                      selected_text
# 0  f9382a1f7b  oooh, sunshine! a patch of sunshine! and it wi...
# the id is 54670ca807 and the string is skype call with billie but my webcam dont work
#        textID                                   selected_text
# 0  54670ca807  skype call with billie but my webcam dont work
# the id is 3ab338c459 and the string is delicious
#        textID selected_text
# 0  3ab338c459     delicious
# the id is c7c7f7f025 and the string is prohibiting
#        textID selected_text
# 0  c7c7f7f025   prohibiting
# the id is 1256e6a4d2 and the string is lol since i got twitter a little while ago, it seems like loads of people setting up an account
#        textID                                      selected_text
# 0  1256e6a4d2  lol since i got twitter a little while ago, it...
# the id is 990cdeae87 and the string is i want to see david cook!!
#        textID               selected_text
# 0  990cdeae87  i want to see david cook!!
# the id is 9a55d83c79 and the string is yeh me 2
#        textID selected_text
# 0  9a55d83c79      yeh me 2
# the id is c8307a482d and the string is learning tat the scenic way din plan to go town but somehow was herded there?
#        textID                                      selected_text
# 0  c8307a482d  learning tat the scenic way din plan to go tow...
# the id is 0a21b662a4 and the string is i don ` t want to do anything specific, i just want to see you and puppy!
#        textID                                      selected_text
# 0  0a21b662a4  i don ` t want to do anything specific, i just...
# the id is 297f7d9e0f and the string is miss braddddddddd
#        textID      selected_text
# 0  297f7d9e0f  miss braddddddddd
# the id is 68901906a4 and the string is toy story 3 trailer premiered with up. i need my computer back.
#        textID                                      selected_text
# 0  68901906a4  toy story 3 trailer premiered with up. i need ...
# the id is 3112944847 and the string is ughh on the phone with hp!
#        textID               selected_text
# 0  3112944847  ughh on the phone with hp!
# the id is 8f8334ffa2 and the string is and - hand made by dan & jenn - sock blockers... made from exotic woods... one of which is called'purple heart '
#        textID                                      selected_text
# 0  8f8334ffa2  and - hand made by dan & jenn - sock blockers....
# the id is 322546026e and the string is yay
#        textID selected_text
# 0  322546026e           yay
# the id is e6c154f9be and the string is sadly
#        textID selected_text
# 0  e6c154f9be         sadly
# the id is e96d849b35 and the string is tis awesome
#        textID selected_text
# 0  e96d849b35   tis awesome
# the id is 124e30d941 and the string is happy
#        textID selected_text
# 0  124e30d941         happy
# the id is fbb5742bbb and the string is _ adel they didn ` t reply yet.. wait till they confirm.. in case somebody might have translated it already..
#        textID                                      selected_text
# 0  fbb5742bbb  _ adel they didn ` t reply yet.. wait till the...
# the id is e90acf3c42 and the string is thats rough.
#        textID selected_text
# 0  e90acf3c42  thats rough.
# the id is 0b0944285d and the string is might have to go back much earlier than expected. bye bye bay area
#        textID                                      selected_text
# 0  0b0944285d  might have to go back much earlier than expect...
# the id is a11da2d3bf and the string is wishin my buddies were playin with me.....
#        textID                               selected_text
# 0  a11da2d3bf  wishin my buddies were playin with me.....
# the id is 161bfc7c8a and the string is good haircut, the ability to listen and the value of not taking yourself too seriously
#        textID                                      selected_text
# 0  161bfc7c8a  good haircut, the ability to listen and the va...
# the id is 4a65010643 and the string is riley hacked my twitter! hahaha : ]
#        textID                        selected_text
# 0  4a65010643  riley hacked my twitter! hahaha : ]
# the id is 1b460c82f0 and the string is big sad face bing doesn ` t work on iphone. it just takes you to the regular mobile live search.
#        textID                                      selected_text
# 0  1b460c82f0  big sad face bing doesn ` t work on iphone. it...
# the id is 43e91a5488 and the string is i liked it.
#        textID selected_text
# 0  43e91a5488   i liked it.
# the id is 410dd99aa3 and the string is man im so sad school is ending but then again high school might be better : o
#        textID                                      selected_text
# 0  410dd99aa3  man im so sad school is ending but then again ...
# the id is b3eadfc565 and the string is hilarious
#        textID selected_text
# 0  b3eadfc565     hilarious
# the id is 480894125b and the string is you ` re the absoute best
#        textID              selected_text
# 0  480894125b  you ` re the absoute best
# the id is 001617fca4 and the string is oh my god!!! i cried so much!!! watch this guys from bgt http : / / bit. ly / 5t5xz
#        textID                                      selected_text
# 0  001617fca4  oh my god!!! i cried so much!!! watch this guy...
# the id is 52f2f23473 and the string is my near daily exercise is starting to show results.
#        textID                                      selected_text
# 0  52f2f23473  my near daily exercise is starting to show res...
# the id is e7e27b0c91 and the string is welcome!
#        textID selected_text
# 0  e7e27b0c91      welcome!
# the id is 834dc73c0c and the string is bout to hit pmark then make one of my final meals wit the housemates..
#        textID                                      selected_text
# 0  834dc73c0c  bout to hit pmark then make one of my final me...
# the id is aeb0e9d730 and the string is : you get to go home and i have to go to work
#        textID                                  selected_text
# 0  aeb0e9d730  : you get to go home and i have to go to work
# the id is c672c9da1d and the string is voted for on cmt. com
#        textID          selected_text
# 0  c672c9da1d  voted for on cmt. com
# the id is cbee1946d3 and the string is just got home from a nice party, just not tired yet
#        textID                                      selected_text
# 0  cbee1946d3  just got home from a nice party, just not tire...
# the id is b1999f0951 and the string is sunburn
#        textID selected_text
# 0  b1999f0951       sunburn
# the id is 25510fbf89 and the string is nice
#        textID selected_text
# 0  25510fbf89          nice
# the id is bcb9426abb and the string is wish
#        textID selected_text
# 0  bcb9426abb          wish
# the id is 0d29624200 and the string is i < 3 rupert grint...... & of the boy, ive accepted tht i do fancy him but im certain he doesnt feel the same so its not worth telling him
#        textID                                      selected_text
# 0  0d29624200  i < 3 rupert grint...... & of the boy, ive acc...
# the id is 3f0f5891ab and the string is love your books
#        textID    selected_text
# 0  3f0f5891ab  love your books
# the id is 0b34e66ea3 and the string is jerk!
#        textID selected_text
# 0  0b34e66ea3         jerk!
# the id is 11de8c0456 and the string is lost
#        textID selected_text
# 0  11de8c0456          lost
# the id is d5712716e9 and the string is well thank your phone for me.
#        textID                  selected_text
# 0  d5712716e9  well thank your phone for me.
# the id is 3f90f95beb and the string is that ` s pretty funny
#        textID          selected_text
# 0  3f90f95beb  that ` s pretty funny
# the id is c108e09b19 and the string is tweetdeck is acting really strange! hum........ reinstall maybe. update on the horizon? or is it just another adobe memory leak
#        textID                                      selected_text
# 0  c108e09b19  tweetdeck is acting really strange! hum..........
# the id is 7223fdccc2 and the string is i so want to go
#        textID    selected_text
# 0  7223fdccc2  i so want to go
# the id is f254748cdb and the string is happy
#        textID selected_text
# 0  f254748cdb         happy
# the id is 256453d14f and the string is it ` s gonna be hot here today too. today is ryan ` s last day of pre - k. i can ` t believe it!
#        textID                                      selected_text
# 0  256453d14f  it ` s gonna be hot here today too. today is r...
# the id is 8fd01857a9 and the string is is dreaming of the weekend... awake!
#        textID                         selected_text
# 0  8fd01857a9  is dreaming of the weekend... awake!
# the id is 37227c0dbf and the string is * * * * me.
#        textID selected_text
# 0  37227c0dbf   * * * * me.
# the id is 20aff2fcb1 and the string is yay but you missed naptime
#        textID               selected_text
# 0  20aff2fcb1  yay but you missed naptime
# the id is ca223af36e and the string is good
#        textID selected_text
# 0  ca223af36e          good
# the id is 90977e9614 and the string is love norton ghost.
#        textID       selected_text
# 0  90977e9614  love norton ghost.
# the id is 433b1ab9ea and the string is comfy
#        textID selected_text
# 0  433b1ab9ea         comfy
# the id is 37771d1bc1 and the string is finally some sleep in silence
#        textID                  selected_text
# 0  37771d1bc1  finally some sleep in silence
# the id is fa99046452 and the string is im just up : - | and its 12 : 43 : o im so lazy thank god its a bank holiday
#        textID                                      selected_text
# 0  fa99046452  im just up : - | and its 12 : 43 : o im so laz...
# the id is 14760477ad and the string is tired.
#        textID selected_text
# 0  14760477ad        tired.
# the id is da908a6635 and the string is i have to poop... is hogging the shitter
#        textID                             selected_text
# 0  da908a6635  i have to poop... is hogging the shitter
# the id is 2053a455e9 and the string is yes! im down to 50 % full on my dvr i was at 98 % like 3 days ago... lol i swear if i didnt have a dvr i would never watch tv
#        textID                                      selected_text
# 0  2053a455e9  yes! im down to 50 % full on my dvr i was at 9...
# the id is 1ea547383b and the string is happy muthath ` s day
#        textID          selected_text
# 0  1ea547383b  happy muthath ` s day
# the id is 6634c62acf and the string is hahaha! alright..
#        textID      selected_text
# 0  6634c62acf  hahaha! alright..
# the id is c7240790da and the string is good for you and congrats
#        textID              selected_text
# 0  c7240790da  good for you and congrats
# the id is 08ede23635 and the string is good to know thanks
#        textID        selected_text
# 0  08ede23635  good to know thanks
# the id is 4e87dcff0e and the string is what are you? flavor of the day?
#        textID                     selected_text
# 0  4e87dcff0e  what are you? flavor of the day?
# the id is 4b0b53bc98 and the string is weathers let me down this morning... ugh!... hada gd nite tho!
#        textID                                      selected_text
# 0  4b0b53bc98  weathers let me down this morning... ugh!... h...
# the id is fd3a622954 and the string is just listened to condre scr and got an invitation to watch their live concert on june 20th in munich http : / / bit. ly / daxa0 # postrock
#        textID                                      selected_text
# 0  fd3a622954  just listened to condre scr and got an invitat...
# the id is e34af4fd97 and the string is happy memories.
#        textID    selected_text
# 0  e34af4fd97  happy memories.
# the id is 0e8aa10a4e and the string is cute picture..
#        textID   selected_text
# 0  0e8aa10a4e  cute picture..
# the id is 29148dc95c and the string is love
#        textID selected_text
# 0  29148dc95c          love
# the id is 56a15cf6ca and the string is hate
#        textID selected_text
# 0  56a15cf6ca          hate
# the id is b99969c2fb and the string is is online http : / / plurk. com / p / stjdg
#        textID                                selected_text
# 0  b99969c2fb  is online http : / / plurk. com / p / stjdg
# the id is b0f3142cb4 and the string is bundy. in 3 days.!!!! warm weather here i come!
#        textID                                    selected_text
# 0  b0f3142cb4  bundy. in 3 days.!!!! warm weather here i come!
# the id is 5ff525b74b and the string is wondering if i cld make things any worse than they already are... answer.. just did!!!
#        textID                                      selected_text
# 0  5ff525b74b  wondering if i cld make things any worse than ...
# the id is 4fd80e66e0 and the string is a dutch marketing agency is asking job applicants to apply in 140 characters or less
#        textID                                      selected_text
# 0  4fd80e66e0  a dutch marketing agency is asking job applica...
# the id is e77a8f8f2d and the string is frustratingly
#        textID  selected_text
# 0  e77a8f8f2d  frustratingly
# the id is 4ea7102112 and the string is i completely agree
#        textID       selected_text
# 0  4ea7102112  i completely agree
# the id is 6a14956779 and the string is if we don ` t pack, she can ` t leave, right?
#        textID                                  selected_text
# 0  6a14956779  if we don ` t pack, she can ` t leave, right?
# the id is 7c2fcb712e and the string is * * * * lol.... where u headed to?
#        textID                       selected_text
# 0  7c2fcb712e  * * * * lol.... where u headed to?
# the id is cdd172d6a7 and the string is glad
#        textID selected_text
# 0  cdd172d6a7          glad
# the id is d2a21b3cb7 and the string is missed
#        textID selected_text
# 0  d2a21b3cb7        missed
# the id is 799e17e7a7 and the string is nice
#        textID selected_text
# 0  799e17e7a7          nice
# the id is 0a49cdbdf6 and the string is miss the soccer moms
#        textID         selected_text
# 0  0a49cdbdf6  miss the soccer moms
# the id is 4a13c1093d and the string is between the garlic pills, the spider bite between your toe ( lol - classic ) and you always being hungry. u are killing me 2 funny
#        textID                                      selected_text
# 0  4a13c1093d  between the garlic pills, the spider bite betw...
# the id is 9407ce6ccc and the string is * sighs * ah well. maybe my second email will clear it up and get him approved.
#        textID                                      selected_text
# 0  9407ce6ccc  * sighs * ah well. maybe my second email will ...
# the id is 820f19ca44 and the string is missed all your tweets again joe, * * * * that time difference!!! ( uk ) dont 4get about your fave supporters in the uk!!! * * * *
#        textID                                      selected_text
# 0  820f19ca44  missed all your tweets again joe, * * * * that...
# the id is 683bb73c09 and the string is - - that came to my mind. so i said it. and it has now been adapted into my family ` s vocabulary
#        textID                                      selected_text
# 0  683bb73c09  - - that came to my mind. so i said it. and it...
# the id is 0d14593b11 and the string is looking forward to body works today
#        textID                        selected_text
# 0  0d14593b11  looking forward to body works today
# the id is 9ac13b3739 and the string is messed up
#        textID selected_text
# 0  9ac13b3739     messed up
# the id is 16ee71e6df and the string is sadly
#        textID selected_text
# 0  16ee71e6df         sadly
# the id is f5d47f04f5 and the string is suffocating
#        textID selected_text
# 0  f5d47f04f5   suffocating
# the id is e131c496a2 and the string is meeting my best friend first thing in the morning to the gym! omg i am still so shocked. i hope you will get better soon
#        textID                                      selected_text
# 0  e131c496a2  meeting my best friend first thing in the morn...
# the id is bc6d7b4364 and the string is lost
#        textID selected_text
# 0  bc6d7b4364          lost
# the id is c87be630b5 and the string is yup theory is great but the reality is beyond imagination... i also made the same planning not knowing vs will fail on me
#        textID                                      selected_text
# 0  c87be630b5  yup theory is great but the reality is beyond ...
# the id is e4ad1684bb and the string is glad
#        textID selected_text
# 0  e4ad1684bb          glad
# the id is f7835156a5 and the string is woot!
#        textID selected_text
# 0  f7835156a5         woot!
# the id is 03bb148b87 and the string is ' i don ` t like monday, i wish it were sunday, cause that ` s my fun day.'that was my freaking jam when i was little. i miss it.
#        textID                                      selected_text
# 0  03bb148b87  ' i don ` t like monday, i wish it were sunday...
# the id is b47c430fda and the string is ????????? - http : / / bit. ly / nack2
#        textID                           selected_text
# 0  b47c430fda  ????????? - http : / / bit. ly / nack2
# the id is 0234e16010 and the string is waiting for the last movie to finish then am test screening ghost of girlfriends past, glass of wine and lolly bag in hand, yay!
#        textID                                      selected_text
# 0  0234e16010  waiting for the last movie to finish then am t...
# the id is be9ed19513 and the string is happy
#        textID selected_text
# 0  be9ed19513         happy
# the id is bf7240df91 and the string is must head back to the office
#        textID                 selected_text
# 0  bf7240df91  must head back to the office
# the id is 2f883c6eb1 and the string is dirty.
#        textID selected_text
# 0  2f883c6eb1        dirty.
# the id is a1320a5050 and the string is camping at black butte lake
#        textID                selected_text
# 0  a1320a5050  camping at black butte lake
# the id is d72a60bee8 and the string is are you getting my messages or do you have to add me to recieve them, soz i ` m new to this
#        textID                                      selected_text
# 0  d72a60bee8  are you getting my messages or do you have to ...
# the id is bc9ebe0002 and the string is i hate my life
#        textID   selected_text
# 0  bc9ebe0002  i hate my life
# the id is 64ddc1f8a2 and the string is sick
#        textID selected_text
# 0  64ddc1f8a2          sick
# the id is 03f6b8d900 and the string is * * * *!
#        textID selected_text
# 0  03f6b8d900      * * * *!
# the id is 2d475b1b23 and the string is depressed
#        textID selected_text
# 0  2d475b1b23     depressed
# the id is 87473f5175 and the string is crying real tears
#        textID      selected_text
# 0  87473f5175  crying real tears
# the id is 7a09871d21 and the string is _ brown been holding onto this one for a while http : / / twitpic. com / 4w5eh
#        textID                                      selected_text
# 0  7a09871d21  _ brown been holding onto this one for a while...
# the id is 96ec2855e4 and the string is wish
#        textID selected_text
# 0  96ec2855e4          wish
# the id is 45cf9ba329 and the string is back from town and my mac crashed on me but it ` s better now
#        textID                                      selected_text
# 0  45cf9ba329  back from town and my mac crashed on me but it...
# the id is bab68144cd and the string is archie andrews what were you thinking?! veronica?
#        textID                                      selected_text
# 0  bab68144cd  archie andrews what were you thinking?! veronica?
# the id is fc49e426f5 and the string is best
#        textID selected_text
# 0  fc49e426f5          best
# the id is a172818c9e and the string is happy mother ` s day
#        textID         selected_text
# 0  a172818c9e  happy mother ` s day
# the id is 036191bb61 and the string is not old enough
#        textID   selected_text
# 0  036191bb61  not old enough
# the id is 3ef85c201c and the string is bummer
#        textID selected_text
# 0  3ef85c201c        bummer
# the id is ea348ea738 and the string is he is the truth! but what about maxwell? you can ` t forget the future father of my children!
#        textID                                      selected_text
# 0  ea348ea738  he is the truth! but what about maxwell? you c...
# the id is fd10f463c9 and the string is the racoons ate our bread!
#        textID               selected_text
# 0  fd10f463c9  the racoons ate our bread!
# the id is e6e02e1be6 and the string is fabulous
#        textID selected_text
# 0  e6e02e1be6      fabulous
# the id is 8112c62d00 and the string is _ in _ a _ story glad i ` m not the only one. he ` s our baby, and i ` m terrified he ` ll think we ` re never coming back.
#        textID                                      selected_text
# 0  8112c62d00  _ in _ a _ story glad i ` m not the only one. ...
# the id is 0f89951346 and the string is stupid
#        textID selected_text
# 0  0f89951346        stupid
# the id is f3ec0395b0 and the string is it ` s very pleasant.
#        textID          selected_text
# 0  f3ec0395b0  it ` s very pleasant.
# the id is 37ffa83550 and the string is thank you!!
#        textID selected_text
# 0  37ffa83550   thank you!!
# the id is cb8c730261 and the string is good
#        textID selected_text
# 0  cb8c730261          good
# the id is be33b5cb9a and the string is again working on the internet shop... don ` t think we will achieve the goal of uploading by the previously set time will keep going
#        textID                                      selected_text
# 0  be33b5cb9a  again working on the internet shop... don ` t ...
# the id is 4fed31099f and the string is sucked so much.
#        textID    selected_text
# 0  4fed31099f  sucked so much.
# the id is de288eb45b and the string is what causes the frustration buddy?
#        textID                       selected_text
# 0  de288eb45b  what causes the frustration buddy?
# the id is 7ab82d9fda and the string is thank you!
#        textID selected_text
# 0  7ab82d9fda    thank you!
# the id is 9d8a45d308 and the string is saddenning depressing dullful upsetting
#        textID                            selected_text
# 0  9d8a45d308  saddenning depressing dullful upsetting
# the id is d25c4179f6 and the string is sorry for my lack of tweets
#        textID                selected_text
# 0  d25c4179f6  sorry for my lack of tweets
# the id is 6cd35dd82e and the string is best
#        textID selected_text
# 0  6cd35dd82e          best
# the id is 65275b51e2 and the string is going to bed cant take thiss any longeerr maan. [ u ]
#        textID                                      selected_text
# 0  65275b51e2  going to bed cant take thiss any longeerr maan...
# the id is 9fae9e3145 and the string is good luck!
#        textID selected_text
# 0  9fae9e3145    good luck!
# the id is e515132ae4 and the string is thanks... i really do appreciate that. i know it will be the hardest thing i have ever done
#        textID                                      selected_text
# 0  e515132ae4  thanks... i really do appreciate that. i know ...
# the id is df3c7485ae and the string is i ` ll miss you guys!
#        textID          selected_text
# 0  df3c7485ae  i ` ll miss you guys!
# the id is bd8ba2ad7e and the string is i just love every little thing about you...
#        textID                                selected_text
# 0  bd8ba2ad7e  i just love every little thing about you...
# the id is 58be40735c and the string is stoooopid thing
#        textID    selected_text
# 0  58be40735c  stoooopid thing
# the id is b5a0a16fd7 and the string is hi simon, let me know when it ` s done
#        textID                           selected_text
# 0  b5a0a16fd7  hi simon, let me know when it ` s done
# the id is 044f146e5c and the string is amazing
#        textID selected_text
# 0  044f146e5c       amazing
# the id is a8e17db0cc and the string is poor little woman with her smushed in head
#        textID                               selected_text
# 0  a8e17db0cc  poor little woman with her smushed in head
# the id is abda0ac082 and the string is is fixin to clean the house for my mom for mother ` s day
#        textID                                      selected_text
# 0  abda0ac082  is fixin to clean the house for my mom for mot...
# the id is b01506af48 and the string is why do you think people say,'save the drama fo yo mama?'i ` m sure even yo mama wouldn ` t wanna listen to ur drama. ode to mother ` s day!
#        textID                                      selected_text
# 0  b01506af48  why do you think people say,'save the drama fo...
# the id is 53969f2468 and the string is i hate that place.
#        textID       selected_text
# 0  53969f2468  i hate that place.
# the id is 4df63939ef and the string is failed
#        textID selected_text
# 0  4df63939ef        failed
# the id is f43efa3560 and the string is she looked soo pretty..
#        textID            selected_text
# 0  f43efa3560  she looked soo pretty..
# the id is c89e41fc7c and the string is follow me too
#        textID  selected_text
# 0  c89e41fc7c  follow me too
# the id is b9ec075666 and the string is bought three books!! yipee!! now who ` s with me on that read - ten - books - during - the - summer thing?
#        textID                                      selected_text
# 0  b9ec075666  bought three books!! yipee!! now who ` s with ...
# the id is ca333e378d and the string is i ` m really bored!
#        textID        selected_text
# 0  ca333e378d  i ` m really bored!
# the id is 5a91b175f6 and the string is goodnight
#        textID selected_text
# 0  5a91b175f6     goodnight
# the id is ac00adda49 and the string is feeling sick
#        textID selected_text
# 0  ac00adda49  feeling sick
# the id is cf9dc7479a and the string is scare
#        textID selected_text
# 0  cf9dc7479a         scare
# the id is 005e2e60d3 and the string is now i need to change my monitor
#        textID                    selected_text
# 0  005e2e60d3  now i need to change my monitor
# the id is 0b1fad03e9 and the string is i know dude, i ` m doing re - runs, making jenny watch them now too so we can have conversations lol. haven ` t been online much
#        textID                                      selected_text
# 0  0b1fad03e9  i know dude, i ` m doing re - runs, making jen...
# the id is 2c72a5582a and the string is what about me?? i vote every day for you!!!!!
#        textID                                  selected_text
# 0  2c72a5582a  what about me?? i vote every day for you!!!!!
# the id is af0778ed50 and the string is fun.
#        textID selected_text
# 0  af0778ed50          fun.
# the id is 1e0416ec46 and the string is just rocked home from maccas, and now signing a petition for big bang to tour aus lol
#        textID                                      selected_text
# 0  1e0416ec46  just rocked home from maccas, and now signing ...
# the id is 1e6f72ea44 and the string is sick.. i no feel so good
#        textID             selected_text
# 0  1e6f72ea44  sick.. i no feel so good
# the id is cc930f7aa8 and the string is eagerly anticipating twitpics
#        textID                  selected_text
# 0  cc930f7aa8  eagerly anticipating twitpics
# the id is 9c202174a3 and the string is lots of tasks to complete today.
#        textID                     selected_text
# 0  9c202174a3  lots of tasks to complete today.
# the id is b9a1df7a8a and the string is sux
#        textID selected_text
# 0  b9a1df7a8a           sux
# the id is 7b3132d3cc and the string is chillen
#        textID selected_text
# 0  7b3132d3cc       chillen
# the id is 5f80970983 and the string is yay doctors now interview then back 2 the doctor ` s for blood work
#        textID                                      selected_text
# 0  5f80970983  yay doctors now interview then back 2 the doct...
# the id is f008d91039 and the string is ahhh memories...
#        textID     selected_text
# 0  f008d91039  ahhh memories...
# the id is c223721eed and the string is i ` m siiiiiickkk i dun feel good!!
#        textID                        selected_text
# 0  c223721eed  i ` m siiiiiickkk i dun feel good!!
# the id is 7f8a3308f8 and the string is nostalgic
#        textID selected_text
# 0  7f8a3308f8     nostalgic
# the id is 3f7adda0a4 and the string is glorious
#        textID selected_text
# 0  3f7adda0a4      glorious
# the id is 6c60cf0bb2 and the string is i feel so sorry
#        textID    selected_text
# 0  6c60cf0bb2  i feel so sorry
# the id is f77651be05 and the string is would wish the severe migrains would stop!!! doc ` s prescriptions arent working
#        textID                                      selected_text
# 0  f77651be05  would wish the severe migrains would stop!!! d...
# the id is aff740a028 and the string is cutest
#        textID selected_text
# 0  aff740a028        cutest
# the id is c3f1116734 and the string is my life would suck
#        textID       selected_text
# 0  c3f1116734  my life would suck
# the id is 4b57011c85 and the string is revising for exams
#        textID       selected_text
# 0  4b57011c85  revising for exams
# the id is cb4266c560 and the string is laughed
#        textID selected_text
# 0  cb4266c560       laughed
# the id is dcb3bb2912 and the string is hi jordan i ` m gonna all of u... i know ur busy and i know ur probably tired. but please reschedule nc. don ` t leave us out.
#        textID                                      selected_text
# 0  dcb3bb2912  hi jordan i ` m gonna all of u... i know ur bu...
# the id is f61b40624e and the string is joy
#        textID selected_text
# 0  f61b40624e           joy
# the id is b6d2229b03 and the string is i ` d love to but i think the trek from london would be a bit too much
#        textID                                      selected_text
# 0  b6d2229b03  i ` d love to but i think the trek from london...
# the id is 299fda8c5b and the string is hey hey
#        textID selected_text
# 0  299fda8c5b       hey hey
# the id is fbea09d42d and the string is isnt the best idea
#        textID       selected_text
# 0  fbea09d42d  isnt the best idea
# the id is 1b62e0c672 and the string is miserable i feel like im gona cry sux!
#        textID                           selected_text
# 0  1b62e0c672  miserable i feel like im gona cry sux!
# the id is 2452a0aa6a and the string is delicious.
#        textID selected_text
# 0  2452a0aa6a    delicious.
# the id is 8a821c6d63 and the string is true.
#        textID selected_text
# 0  8a821c6d63         true.
# the id is 0f93ebfb23 and the string is lol, get watching it again hehe
#        textID                    selected_text
# 0  0f93ebfb23  lol, get watching it again hehe
# the id is dd655c5aee and the string is hope you did great
#        textID       selected_text
# 0  dd655c5aee  hope you did great
# the id is e94ceb6edd and the string is btw - downloaded iphone 3. 0 sdk
#        textID                     selected_text
# 0  e94ceb6edd  btw - downloaded iphone 3. 0 sdk
# the id is 61e8b484df and the string is bummerrr
#        textID selected_text
# 0  61e8b484df      bummerrr
# the id is 5be41389ce and the string is sad
#        textID selected_text
# 0  5be41389ce           sad
# the id is bd0f0ebc57 and the string is me? a doctor? * laughs * oh, no, no, no. i was _ crane ` s patient at arkham aslyum, but now i work for him
#        textID                                      selected_text
# 0  bd0f0ebc57  me? a doctor? * laughs * oh, no, no, no. i was...
# the id is 772ba56ce6 and the string is great
#        textID selected_text
# 0  772ba56ce6         great
# the id is 390f00c85a and the string is weird
#        textID selected_text
# ...
# the id is 2cc6d6b3e6 and the string is haha!
#        textID selected_text
# 0  2cc6d6b3e6         haha!
# the id is 4ca97418b7 and the string is oh that totally works too
#        textID              selected_text
# 0  4ca97418b7  oh that totally works too
# the id is be2fadb2bc and the string is psa : : : : : being that i ` ve been usuing twiddict - my last 14 tweets have yet to show on the bored. bare w me.
#        textID                                      selected_text
# 0  be2fadb2bc  psa : : : : : being that i ` ve been usuing tw...
# the id is 1c0b70106f and the string is hard to prove, its all hearsay accounts... it bugs me...
#        textID                                      selected_text
# 0  1c0b70106f  hard to prove, its all hearsay accounts... it ...
# the id is 4d9a27e25a and the string is don ` t you need a server and someone who knows how to program to use wordpress? love to but my knowledge is limited right now
#        textID                                      selected_text
# 0  4d9a27e25a  don ` t you need a server and someone who know...
# the id is 834651667b and the string is enjoyed
#        textID selected_text
# 0  834651667b       enjoyed
# the id is 688784c5a9 and the string is excited
#        textID selected_text
# 0  688784c5a9       excited
# the id is 7d32d4866a and the string is lucky.
#        textID selected_text
# 0  7d32d4866a        lucky.
# the id is 0cbab4e443 and the string is [ sarah mcglaclan song in background ] please donate to jpnnbak ` fund of'dinero for the cable bill'think of how you will make her
#        textID                                      selected_text
# 0  0cbab4e443  [ sarah mcglaclan song in background ] please ...
# the id is d57bd01b7e and the string is * * * * sucha shame
#        textID        selected_text
# 0  d57bd01b7e  * * * * sucha shame
# the id is a5912f5b7b and the string is gday... do you know if nhibernate has issues with com interop ( vb6 < - >. net wrapper < - >. net + nhibernate dll )? i ` m getting crazy
#        textID                                      selected_text
# 0  a5912f5b7b  gday... do you know if nhibernate has issues w...
# the id is b0f7ac544d and the string is exhausted and sick )
#        textID         selected_text
# 0  b0f7ac544d  exhausted and sick )
# the id is 73fd2537e6 and the string is nice
#        textID selected_text
# 0  73fd2537e6          nice
# the id is 20f35978fb and the string is wishin i was sexin somebody!!!
#        textID                   selected_text
# 0  20f35978fb  wishin i was sexin somebody!!!
# the id is 9a8cde88ea and the string is nice.
#        textID selected_text
# 0  9a8cde88ea         nice.
# the id is 9f48b1d3fa and the string is i can ` t get in, i ` m in a waiting room
#        textID                              selected_text
# 0  9f48b1d3fa  i can ` t get in, i ` m in a waiting room
# the id is 79bd7de23f and the string is glad
#        textID selected_text
# 0  79bd7de23f          glad
# the id is 6b3c3e22d5 and the string is i didnt save those links! i dont need distractions.. i just need motivation
#        textID                                      selected_text
# 0  6b3c3e22d5  i didnt save those links! i dont need distract...
# the id is b411bd3afb and the string is pain!
#        textID selected_text
# 0  b411bd3afb         pain!
# the id is 469196b094 and the string is can sum1 tells me how 2 vote 4 miley? it seems sum peeple r still voting i went 2 mtv. com nd it seems i cant vote
#        textID                                      selected_text
# 0  469196b094  can sum1 tells me how 2 vote 4 miley? it seems...
# the id is 7b65a847b6 and the string is thanks dear.. wish you the best too
#        textID                        selected_text
# 0  7b65a847b6  thanks dear.. wish you the best too
# the id is cc28178ef0 and the string is i said hi to u
#        textID   selected_text
# 0  cc28178ef0  i said hi to u
# the id is 4200e8b73c and the string is madness
#        textID selected_text
# 0  4200e8b73c       madness
# the id is 77a7b3282b and the string is oh well i hope she gets better
#        textID                   selected_text
# 0  77a7b3282b  oh well i hope she gets better
# the id is 76b40b8c3d and the string is http : / / twitpic. com / 1aida - snood
#        textID                            selected_text
# 0  76b40b8c3d  http : / / twitpic. com / 1aida - snood
# the id is 1b6fe730fd and the string is can ` t wait
#        textID selected_text
# 0  1b6fe730fd  can ` t wait
# the id is 2a04e6e839 and the string is managed to find a bottle of pimm ` s! if only we had the weather to go with it
#        textID                                      selected_text
# 0  2a04e6e839  managed to find a bottle of pimm ` s! if only ...
# the id is f944be482a and the string is congrats
#        textID selected_text
# 0  f944be482a      congrats
# the id is d461b50edb and the string is bored
#        textID selected_text
# 0  d461b50edb         bored
# the id is d8ab713a6a and the string is i love it. happy star wars day everyone!!!!
#        textID                                selected_text
# 0  d8ab713a6a  i love it. happy star wars day everyone!!!!
# the id is e838d1f366 and the string is oh it was marathon * * * *? mahasha
#        textID                        selected_text
# 0  e838d1f366  oh it was marathon * * * *? mahasha
# the id is 885b8f47f7 and the string is yes sir i sure did.
#        textID        selected_text
# 0  885b8f47f7  yes sir i sure did.
# the id is ac3b9688c6 and the string is very very very very cool.
#        textID              selected_text
# 0  ac3b9688c6  very very very very cool.
# the id is 0f93a7a6ff and the string is wish
#        textID selected_text
# 0  0f93a7a6ff          wish
# the id is 9a38abcf54 and the string is congrats
#        textID selected_text
# 0  9a38abcf54      congrats
# the id is 863e09ee74 and the string is have fun! i am sad to not be with you guys
#        textID                               selected_text
# 0  863e09ee74  have fun! i am sad to not be with you guys
# the id is 9501aabea3 and the string is died
#        textID selected_text
# 0  9501aabea3          died
# the id is 40ada63a36 and the string is have a huge block of snack chocolate here. tis calling my name already
#        textID                                      selected_text
# 0  40ada63a36  have a huge block of snack chocolate here. tis...
# the id is c956722677 and the string is my room is too hot
#        textID       selected_text
# 0  c956722677  my room is too hot
# the id is 1c6ce0a7e3 and the string is yes.
#        textID selected_text
# 0  1c6ce0a7e3          yes.
# the id is 5648799bc4 and the string is _ ellen and she ` s 9. 5 and a rescue.. bad hips. she deserves pampering! she ` s full of life though!!
#        textID                                      selected_text
# 0  5648799bc4  _ ellen and she ` s 9. 5 and a rescue.. bad hi...
# the id is 59fd038492 and the string is will play quake3 in 3min
#        textID             selected_text
# 0  59fd038492  will play quake3 in 3min
# the id is 0ef8ddf4a1 and the string is hope it went well!
#        textID       selected_text
# 0  0ef8ddf4a1  hope it went well!
# the id is 50ba66785b and the string is go on msn. i need to talk to you about something that happened today
#        textID                                      selected_text
# 0  50ba66785b  go on msn. i need to talk to you about somethi...
# the id is 827fa68ce4 and the string is best
#        textID selected_text
# 0  827fa68ce4          best
# the id is a60b818d1d and the string is goodnight tweeps.
#        textID      selected_text
# 0  a60b818d1d  goodnight tweeps.
# the id is 316a1d0f4c and the string is aww, we will miss
#        textID      selected_text
# 0  316a1d0f4c  aww, we will miss
# the id is 1dc7f3d536 and the string is what are those barrels made of? hey pass that barrel
#        textID                                      selected_text
# 0  1dc7f3d536  what are those barrels made of? hey pass that ...
# the id is c08d28468b and the string is thanks
#        textID selected_text
# 0  c08d28468b        thanks
# the id is 043c3b53f8 and the string is can ` t wait
#        textID selected_text
# 0  043c3b53f8  can ` t wait
# the id is 5fc6e71643 and the string is bored, making a mothers day card
#        textID                     selected_text
# 0  5fc6e71643  bored, making a mothers day card
# the id is 27829d97bd and the string is literally cannot escape
#        textID            selected_text
# 0  27829d97bd  literally cannot escape
# the id is 603a6f30be and the string is i think max ( my cat ) may really be gone
#        textID                              selected_text
# 0  603a6f30be  i think max ( my cat ) may really be gone
# the id is f13fd6b067 and the string is ` m working on a logo on photoshop & it didn ` t work out.. hehe.. try again lah..
#        textID                                      selected_text
# 0  f13fd6b067  ` m working on a logo on photoshop & it didn `...
# the id is 6bda8dca4d and the string is # vegas it sucks
#        textID     selected_text
# 0  6bda8dca4d  # vegas it sucks
# the id is b70db9bf31 and the string is hurt
#        textID selected_text
# 0  b70db9bf31          hurt
# the id is c9980ac0cd and the string is fun!
#        textID selected_text
# 0  c9980ac0cd          fun!
# the id is 8798f0a924 and the string is you know who helps me almost everyday?
#        textID                           selected_text
# 0  8798f0a924  you know who helps me almost everyday?
# the id is edef93288d and the string is sadly
#        textID selected_text
# 0  edef93288d         sadly
# the id is 9f345b18c5 and the string is totally agree, she wasn ` t even as good as the judges said wither! just said it to make her feel better
#        textID                                      selected_text
# 0  9f345b18c5  totally agree, she wasn ` t even as good as th...
# the id is 5f857f8279 and the string is wants to listen to musiq soulchild, but it is not on the ipod
#        textID                                      selected_text
# 0  5f857f8279  wants to listen to musiq soulchild, but it is ...
# the id is 391211cd64 and the string is fun
#        textID selected_text
# 0  391211cd64           fun
# the id is b01c4cd28a and the string is that ` s me right now, all i can do is stare at everyone else working on thier laptops
#        textID                                      selected_text
# 0  b01c4cd28a  that ` s me right now, all i can do is stare a...
# the id is 3a92bdf00a and the string is nice cakes
#        textID selected_text
# 0  3a92bdf00a    nice cakes
# the id is d24ea15375 and the string is it was sunny when i entered the sub - basement. now it ` s raining.
#        textID                                      selected_text
# 0  d24ea15375  it was sunny when i entered the sub - basement...
# the id is c3c168bc80 and the string is orange vitamin water 10 is my new addiction u should try it.
#        textID                                      selected_text
# 0  c3c168bc80  orange vitamin water 10 is my new addiction u ...
# the id is 189ea0d26f and the string is yay thanku!
#        textID selected_text
# 0  189ea0d26f   yay thanku!
# the id is fa117106ef and the string is i ` m so bummed
#        textID    selected_text
# 0  fa117106ef  i ` m so bummed
# the id is f66bda14c6 and the string is we are a backstreet fans and we are proud about it!!
#        textID                                      selected_text
# 0  f66bda14c6  we are a backstreet fans and we are proud abou...
# the id is cf3dafabb3 and the string is .. so i can only recover 10 photos
#        textID                       selected_text
# 0  cf3dafabb3  .. so i can only recover 10 photos
# the id is 242910ff98 and the string is thank you for saying that wish you and the others a nice day, greets
#        textID                                      selected_text
# 0  242910ff98  thank you for saying that wish you and the oth...
# the id is 60e5c2c335 and the string is bored
#        textID selected_text
# 0  60e5c2c335         bored
# the id is 72b5155719 and the string is killers are coming to td banknorth in boston on 9 / 4 at 7 : 30pm. and, i can ` t go.
#        textID                                      selected_text
# 0  72b5155719  killers are coming to td banknorth in boston o...
# the id is bbfe533366 and the string is in my moms hair salon, dying my hair
#        textID                         selected_text
# 0  bbfe533366  in my moms hair salon, dying my hair
# the id is 4cb0ab19ed and the string is good morning, to all the mommies happy mothers day.
#        textID                                      selected_text
# 0  4cb0ab19ed  good morning, to all the mommies happy mothers...
# the id is 58e2a00ab8 and the string is that ` s not good
#        textID      selected_text
# 0  58e2a00ab8  that ` s not good
# the id is 0a0e2a4f78 and the string is thanks! i love it
#        textID      selected_text
# 0  0a0e2a4f78  thanks! i love it
# the id is 975554343f and the string is ridiculous
#        textID selected_text
# 0  975554343f    ridiculous
# the id is c7be378db2 and the string is im riding the highs and lows of moods now.... chores blow
#        textID                                      selected_text
# 0  c7be378db2  im riding the highs and lows of moods now.... ...
# the id is 87737f8e62 and the string is hate it
#        textID selected_text
# 0  87737f8e62       hate it
# the id is 558fe1316b and the string is on a 10min brake. at wrrkk... its 11 : 06 and its over at. 11 : 16
#        textID                                      selected_text
# 0  558fe1316b  on a 10min brake. at wrrkk... its 11 : 06 and ...
# the id is a6687519e2 and the string is ok outta all 981 of my followers, only about 10 of u ive talked to lol dont be shy i dont biteeee
#        textID                                      selected_text
# 0  a6687519e2  ok outta all 981 of my followers, only about 1...
# the id is 91f8e27d4c and the string is thanks
#        textID selected_text
# 0  91f8e27d4c        thanks
# the id is 9a10e4813f and the string is where ` d the songs go on the site, i want'do you'on this computer too
#        textID                                      selected_text
# 0  9a10e4813f  where ` d the songs go on the site, i want'do ...
# the id is 2b31cedc6d and the string is woohoo!! my faves!!!
#        textID         selected_text
# 0  2b31cedc6d  woohoo!! my faves!!!
# the id is db783cf66a and the string is no school today, teacher cancelled the lesson chillin `
#        textID                                      selected_text
# 0  db783cf66a  no school today, teacher cancelled the lesson ...
# the id is 036cd6abb0 and the string is hurt.
#        textID selected_text
# 0  036cd6abb0         hurt.
# the id is e965e50c60 and the string is my hair dresser passed away yesterday from breast cancer she was the greatest hair dresser i ` d ever been to!
#        textID                                      selected_text
# 0  e965e50c60  my hair dresser passed away yesterday from bre...
# the id is b1c36b70a4 and the string is i was supposed to go tomorrow tooooo, but have to use gas and ticket money to pay for car inspection fee.
#        textID                                      selected_text
# 0  b1c36b70a4  i was supposed to go tomorrow tooooo, but have...
# the id is 4d2de9d1af and the string is best
#        textID selected_text
# 0  4d2de9d1af          best
# the id is 0c2e7ab834 and the string is happy
#        textID selected_text
# 0  0c2e7ab834         happy
# the id is 0bb5b4d19c and the string is friday evening...... what to do, what to do. i have to idea.
#        textID                                      selected_text
# 0  0bb5b4d19c  friday evening...... what to do, what to do. i...
# the id is e5f0e6ef4b and the string is tired
#        textID selected_text
# 0  e5f0e6ef4b         tired
# the id is 416863ce47 and the string is thanks
#        textID selected_text
# 0  416863ce47        thanks
# the id is 6332da480c and the string is depression..
#        textID selected_text
# 0  6332da480c  depression..
# the id is df1baec676 and the string is i love your videos!
#        textID        selected_text
# 0  df1baec676  i love your videos!
# the id is 469e15c5a8 and the string is omgssh ang cute
#        textID    selected_text
# 0  469e15c5a8  omgssh ang cute

# %%
# load model
prediction.to_csv('submission.csv', index=False)

# %%
#tokenizer.save_vocabulary('../models_trained/vocab.txt')

# %%
"""
def targets_(text, selected_text):
    text = " ".join(str(text).split())
    selected_text = " ".join(str(selected_text).split())
    len_st= len(selected_text)
    idx0 = None
    idx1 = None
    for ind in (i for i, e in enumerate(text) if e == selected_text[0]):
        
        if text[ind: ind+len_st] == selected_text:
            idx0 = ind
            idx1 = ind + len_st - 1
            break

    char_targets = [0] * len(text)
    if idx0 != None and idx1 != None:
        for ct in range(idx0, idx1 + 1):
            char_targets[ct] = 1
    
    tok_tweet = tokenizer.encode_plus(text, return_offsets_mapping = True)
    
    tweet_offsets = tok_tweet.get('offset_mapping')[1:-1]
    
    target_idx = []
    for j, (offset1, offset2) in enumerate(tweet_offsets):
        if sum(char_targets[offset1: offset2]) > 0:
            target_idx.append(j)
    
    target_start = target_idx[0]
    targets_end = target_idx[-1]
    filtered_output = ''
    tweet_offsets
    for ix in range(target_start, targets_end + 1):
        #print(text[tweet_offsets[ix][0]:tweet_offsets[ix][1]])
        filtered_output += text[tweet_offsets[ix][0]:tweet_offsets[ix][1]]
        if (ix+1) < len(tweet_offsets) and tweet_offsets[ix][1] < tweet_offsets[ix+1][0]:
            filtered_output += " "
    print(filtered_output)
    return target_start, targets_end, tok_tweet
"""
